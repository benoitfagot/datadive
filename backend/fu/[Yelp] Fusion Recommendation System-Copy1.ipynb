# %% [markdown]
# <a id='menu'></a>
# # Menu

# %% [markdown]
# [1. Data Processing](#data_proc)
#
# [2. Geolocalisation](#geo_loc)
#
# [3. Popularity](#pop)
#
# [4. Content Based](#content)
#
# [5. Collaborative Filtering](#cf)
#
# - [5.1 Model Based SVD](#cf_model)
#
# - [5.2 Memory Based Memory](#cf_memory)

# %% [markdown]
# # Libraries

# %% [markdown]
# **Machine Learning**

# %%
import pandas as pd
import numpy as np
import nltk
import pickle
from sklearn.metrics.pairwise import cosine_similarity
from sklearn import preprocessing

# %% [markdown]
# **Word2Vec**

# %%
from nltk.tokenize import word_tokenize
import gensim 
from gensim.models import Word2Vec
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/hongphuc95/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# **Visualization**

# %%
import folium
import html

# %%
import time

# %% [markdown]
# **Path**

# %%
data_path = "/home/hongphuc95/notebookteam/dataset/"

# %%
api_path = "/home/hongphuc95/notebookteam/api/"

# %%
import sys
pathModulesES = '../sauceforyall/'
sys.path.append(pathModulesES)
from yelpquery import YelpQuery
from pandasticsearch import Select
ye = YelpQuery()

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# <a id='data_proc'></a>
# # 1. Load data

# %% [markdown]
# [Back to menu](#menu)

# %%
business_df = pd.read_json(data_path + "business.json", lines=True)

# %%
business_df = business_df.dropna(subset=["categories"])

# %%
#review_df = pd.read_json(data_path + "cleaned/review_cleaned_2016_2019.json", lines=True)

# %% [markdown]
# ## 1.1 Useful functions

# %%
def business_details(business_df, review_df):
    business_df = business_df[["business_id", "name", "categories", "address", "city", "state", "latitude", "longitude", "stars", "review_count"]]
    new_df = pd.merge(business_df, review_df, how="inner", on="business_id")
    return new_df

# %%
def show_map(loc, radius=2000, popularity=None, contentbased=None, cf=None):
    lat = loc["latitude"]
    long = loc["longitude"]
    mp = folium.Map(location=[lat, long], zoom_start=12, radius=200000, fill_color='#3186cc', line_color='#3186cc')
    
    if popularity is not None:
        for _, r in popularity.iterrows():
            folium.Marker(
                        location =[r.latitude, r.longitude], 
                        popup = html.escape(
                            r["name"]) + '<br>' + 
                            'Stars: ' + str(r.stars) + '<br>' + 
                            'Reviews: ' + str(r.review_count) + '<br>' + 
                            'Categories: ' + str(r.categories) + '<br>',    
                        icon = folium.Icon(color='blue')).add_to(mp)

    if contentbased is not None:
        for _, r in contentbased.iterrows():
            folium.Marker(
                        location =[r.latitude, r.longitude], 
                        popup = html.escape(
                            r["name"]) + '<br>' + 
                            'Stars: ' + str(r.stars) + '<br>' + 
                            'Reviews: ' + str(r.review_count) + '<br>' + 
                            'Categories: ' + str(r.categories) + '<br>',    
                        icon = folium.Icon(color='orange')).add_to(mp)
            
    if cf is not None:
        for _, r in cf.iterrows():
            folium.Marker(
                        location =[r.latitude, r.longitude], 
                        popup = html.escape(
                            r["name"]) + '<br>' + 
                            'Stars: ' + str(r.stars) + '<br>' + 
                            'Reviews: ' + str(r.review_count) + '<br>' + 
                            'Categories: ' + str(r.categories) + '<br>',    
                        icon = folium.Icon(color='red')).add_to(mp)
            
    return mp

# %% [markdown]
# <a id='geo_loc'></a>
# # 2. Geolocalisation

# %% [markdown]
# [Back to menu](#menu)

# %%
from geopy.exc import GeocoderTimedOut, GeocoderServiceError, GeocoderUnavailable
from geopy.geocoders import Nominatim
from math import radians, cos, sin, asin, sqrt
import requests


class Geolocation:
    token = "5e599797dbecfc222d30063da4b86640"
    send_url = "http://api.ipstack.com/check?access_key=" + token

    def __init__(self, business_df):
        self.business_df = business_df
        self.location = {}
        self.distance_df = pd.DataFrame()
        self.geolocator = Nominatim(user_agent="Data_Dive_Prod")
        
    def normalize(self, df):
        dataNorm = ((df - df.min()) / (df.max() - df.min()))
        return dataNorm

    def reset(self):
        self.location = {}
        self.distance_df = pd.DataFrame()

    def haversine_distance(self, lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between two points
        on the earth (specified in decimal degrees)
        """
        # convert decimal degrees to radians
        lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

        # haversine formule
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
        c = 2 * asin(sqrt(a))
        r = 6371  # Radius of earth in kilometers.
        res = c * r
        return np.round(res, 4)

    def show_current_location(self):
        logger.info("Current location: (Lat: %s, Long: %s)" % (self.location["latitude"], self.location["longitude"]))

    def get_current_location(self):
        return self.location

    def get_business_nearby(self):
        return self.distance_df

    def get_info_coordinate(self, coordinate):
        gps = str(coordinate["latitude"]) + ',' + str(coordinate["longitude"])
        location = self.geolocator.reverse(gps)
        self.location["city"] = location.raw["address"]["city"]
        self.location["country"] = location.raw["address"]["country"]
        self.show_current_location()

    def get_coordinate_address(self, address):
        location = None
        try:
            location = self.geolocator.geocode(address)
        except (GeocoderTimedOut, GeocoderServiceError, GeocoderUnavailable):
            time.sleep(1)
            try:
                location = self.geolocator.geocode(address)
            except (
                    GeocoderTimedOut, GeocoderServiceError,
                    GeocoderUnavailable):
                logger.info('GeocoderServiceError occored')
                return None, None

        logger.info(location)
        if location:
            self.location["latitude"] = location.latitude
            self.location["longitude"] = location.longitude
            coordinate = {"latitude": location.latitude,
                          "longitude": location.longitude}
            self.get_info_coordinate(coordinate=coordinate)

    def get_coordinate_ip_address(self):
        geo_req = requests.get(self.send_url)
        response = geo_req.json()
        self.location["latitude"] = float(response["latitude"])
        self.location["longitude"] = float(response["longitude"])
        self.location["city"] = response["city"]
        self.location["country"] = response["country_name"]
        self.show_current_location()

    def get_neighbors_recommend(self, lookup="", engine=True, rec_range=5):

        if engine:
            if not lookup:
                self.get_coordinate_ip_address()
            else:
                self.get_coordinate_address(lookup)
        else:
            self.location = lookup
            self.get_info_coordinate(coordinate=lookup)

        self.distance_df = pd.DataFrame()
        self.distance_df = self.business_df[["business_id", "longitude", "latitude"]]
        self.distance_df["distance"] = self.distance_df.apply(
            lambda x: self.haversine_distance(self.location["latitude"], self.location["longitude"], x["latitude"],
                                              x["longitude"]),
            axis=1)
        self.distance_df = self.distance_df.sort_values(ascending=True, by="distance").reset_index(drop=True)
        self.distance_df = self.distance_df[self.distance_df["distance"] <= rec_range][["business_id", "distance"]]

        # Normalization
        self.distance_df["geo_score"] = self.normalize(self.distance_df["distance"])
        self.distance_df["geo_score"] = 1 - self.distance_df["geo_score"]

# %%
class EngineGeo:

    def __init__(self, business_df):
        self.geoloc = Geolocation(business_df=business_df)
        
    def reset(self):
        self.geoloc.reset()

    def get_business_nearby(self):
        return self.geoloc.get_business_nearby()

    def get_current_location(self):
        return self.geoloc.get_current_location()

    def recommend(self, lookup="", engine=True, rec_range=5):
        self.geoloc.get_neighbors_recommend(lookup=lookup, engine=engine, rec_range=rec_range)

# %%
engine_geo = EngineGeo(business_df)

# %%
#engine_geo.get_coordinate_address("Las Vegas")

# %%
engine_geo.recommend(lookup="Las Vegas", engine=True)
# Out:
# INFO:__main__:Las Vegas, Clark County, Nevada, United States of America
# INFO:__main__:Current location: (Lat: 36.1672559, Long: -115.1485163)
# /home/hongphuc95/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %%
engine_geo.get_current_location()
# Out:
# {'latitude': 36.1672559,
#  'longitude': -115.1485163,
#  'city': 'Las Vegas',
#  'country': 'United States of America'}

# %%
business_nearby = engine_geo.get_business_nearby()

# %%
business_nearby
# Out:
#                  business_id  distance  geo_score
# 0     3fdtp-bzoE4ZgTakkcEBzQ    0.0218   1.000000
# 1     Vyadl8RsxaFaAFjm98lNTQ    0.0218   1.000000
# 2     VhazKK6zbHrdJaN-bmeHbQ    0.0361   0.997127
# 3     j5pWQfzFuJdYUXb-vKHgyA    0.1157   0.981137
# 4     jmketuCDahSV1-47orzdMg    0.1164   0.980997
# ...                      ...       ...        ...
# 5197  B19KKE75ZxqoR3EDuvA1qw    4.9921   0.001567
# 5198  cPtybPHvMvZygjLkgvM4GA    4.9930   0.001386
# 5199  FhqoXrpfw5ji_Qoh4GcJMg    4.9944   0.001105
# 5200  PZ3qgjUMg8akZaP0CssYNA    4.9997   0.000040
# 5201  csaF_zqfoENAn4g1wJrgIA    4.9999   0.000000
#
# [5202 rows x 3 columns]

# %% [markdown]
# <a id='pop'></a>
# # 3. Popularity Based

# %% [markdown]
# [Back to menu](#menu)

# %% [markdown]
# ## 3.1 Methods

# %%
class Popularity:

    def __init__(self, business_df, ye):
        self.business_df = business_df
        self.ye = ye

    def get_model_name(self):
        return self.MODEL_NAME
    
    def normalize(self, df):
        dataNorm = ((df - df.min()) / (df.max() - df.min()))
        return dataNorm

    def recommend(self, top_n=50, filters={}, geo_w=0.5, pop_w=0.5):
        mask = np.array([])
        recommendations_df = pd.DataFrame()
        nearby_df = pd.DataFrame()
        if filters:
            if "nearby" in filters and not filters["nearby"].empty:
                nearby_df = filters["nearby"]
                nearby_ids = nearby_df["business_id"].values
                if mask.size == 0:
                    mask = nearby_ids
                else:
                    mask = np.intersect1d(mask, nearby_ids)

            if "categories" in filters and filters["categories"]:
                mask_cat = self.business_df[self.business_df["categories"].str.contains(filters["categories"])][
                    "business_id"].values
                mask = np.intersect1d(mask, mask_cat)

            # review_df = self.review_df[self.review_df["business_id"].isin(mask)]
            if mask.size > 0:
                mustArray = [
                    self.ye.bodyMultivalueTerm("business_id.keyword", np.unique(mask).tolist()),
                    self.ye.bodyRange("date", gteValue="2016-01-01", lteValue="2018-12-31")
                ]
                review_fisrt_chunk = self.ye.getComplexeQuery(index="yelp-review*",
                                                              mustArray=mustArray, filterArray=[],
                                                              exclude=["text", "@timestamp", "@version", "cool",
                                                                       "useful",
                                                                       "funny"], size=2000)

                print("Total reviews retrieved: %d" % (review_fisrt_chunk["hits"]["total"]["value"]))
                review_df = self.ye.getResultScrolling(review_fisrt_chunk)

                recommendations_df = review_df.groupby("business_id")["stars"] \
                    .agg(["sum", "count"]) \
                    .reset_index()

                recommendations_df["ratings_avg"] = (recommendations_df["sum"] / recommendations_df["count"])
                recommendations_df = recommendations_df \
                    .sort_values(ascending=False, by="ratings_avg") \
                
                #Normalization of popularity score
                recommendations_df["score"] = self.normalize(recommendations_df["ratings_avg"])
                

                if not nearby_df.empty:
                    recommendations_df = pd.merge(left=recommendations_df, right=nearby_df, how="inner",
                                                  on="business_id")
                    recommendations_df = recommendations_df.rename(
                        columns={"score": "pop_score"})

                    recommendations_df["geo_score"] = recommendations_df["geo_score"] * geo_w
                    recommendations_df["pop_score"] = recommendations_df["pop_score"] * pop_w
                    recommendations_df["score"] = recommendations_df["geo_score"] + recommendations_df["pop_score"]

                    recommendations_df = recommendations_df.sort_values(ascending=False, by="score")

                recommendations_df = recommendations_df.head(top_n)

        return recommendations_df

# %%
class EnginePopularity:

    def __init__(self, business_df, ye):
        self.pop = Popularity(business_df=business_df, ye=ye)

    def predict(self, top_n=50, filters={}):
        return self.pop.recommend(top_n=top_n, filters=filters)

# %% [markdown]
# ## 3.2 Test

# %%
engine_pop = EnginePopularity(business_df, ye)

# %%
filters={}
filters["nearby"] = business_nearby
filters["categories"] = "Hotels"

# %%
rec_pop = engine_pop.predict(filters=filters, top_n=50)
# Out:
# INFO:elasticsearch:POST http://47.91.72.40:9200/yelp-review*/_search?_source_excludes=text%2C%40timestamp%2C%40version%2Ccool%2Cuseful%2Cfunny&_source_includes=&scroll=1m&size=2000 [status:200 request:5.004s]
# Total reviews retrieved: 18844
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:5.918s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:4.797s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:4.236s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:1.990s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.537s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.609s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.574s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.220s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.137s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.029s]

# %%
rec_pop
# Out:
#                 business_id     sum  count  ratings_avg  pop_score  distance  \
# 38   fY0RCsymg465GQ7tmxLYog    84.0     17     4.941176   0.492647    0.4559
# 6    ff-bUaqzSnyAOzW_Qtd65A    65.0     13     5.000000   0.500000    0.5594
# 9    8gYkL76weP9dmd-W8NOeqw    10.0      2     5.000000   0.500000    0.5915
# 27   OIc8vVH1MTmObFeeoc0LFA    10.0      2     5.000000   0.500000    0.6687
# 14   ovFnrmsT5rUpbAQE1r-V0Q    70.0     14     5.000000   0.500000    0.6738
# 20   LklurWnK8agxFp6G-v1CMg    35.0      7     5.000000   0.500000    0.7311
# 19   A_lTCKAfKQKhUiOUyx8-3A     5.0      1     5.000000   0.500000    0.8015
# 13   fAU948kCaESzxAD_nF7rYw     5.0      1     5.000000   0.500000    0.8350
# 1    uAX_EAU1r6J3JwPeX7uGrA    15.0      3     5.000000   0.500000    0.8350
# 48   cKgkSMcPXwWTzPrJRpa2qw   128.0     27     4.740741   0.467593    0.8350
# 58   d6_UHGiMQb5_m8mi_tRc2Q   178.0     41     4.341463   0.417683    0.5494
# 67   VG0nWxGsPixYLsyi49gyxQ  1601.0    376     4.257979   0.407247    0.5447
# 53   y0W8tP-ZRfGbYBzS_1FqeQ    88.0     19     4.631579   0.453947    1.0271
# 56   Zq7vhh8wnqPMoW1EXTeIzg    31.0      7     4.428571   0.428571    0.8350
# 64   PWFB8WyJGaFBWfcrwcn9Lw   137.0     32     4.281250   0.410156    0.6976
# 32   VPVV0W_loOx7M8wNAcRLtw     5.0      1     5.000000   0.500000    1.6101
# 10   _Lm7t08Bnq_ai-nQkKO5lQ     5.0      1     5.000000   0.500000    1.6170
# 65   8QWPlVQ6D-OExqXoaD2Z1g    94.0     22     4.272727   0.409091    0.7538
# 61   vSrlrHuK_2DoGcGUPC9aqw    26.0      6     4.333333   0.416667    0.8462
# 69   mSvclkxQVT6IpZOZ_OrByw    21.0      5     4.200000   0.400000    0.7267
# 42   ndTINKMlSIwMp6dEKVXeAg    34.0      7     4.857143   0.482143    1.6312
# 88   i9rI_eLMlV6cowiZGVzh2Q    15.0      4     3.750000   0.343750    0.2970
# 72   diJLOTB7YfItRLcEr55MoQ    58.0     14     4.142857   0.392857    0.9066
# 83   1qTx9z8RMz7RIYKAfnpZ0A   132.0     35     3.771429   0.346429    0.4553
# 12   fJTzF7HR7TaurZ475YZ86w    15.0      3     5.000000   0.500000    2.0219
# 100  j6D75GAJu6LdvRR1_OsxnA    28.0      8     3.500000   0.312500    0.2102
# 23   ZU_BvNdn7GTytItF04POmg    10.0      2     5.000000   0.500000    2.2447
# 7    JcKtixWaFVOVR690WUiC-A    20.0      4     5.000000   0.500000    2.2447
# 17   CWh5Jvne98_jz0GO7hbzHw    45.0      9     5.000000   0.500000    2.2447
# 16   AT4cfxVgGIy8vKY66ApU7g     5.0      1     5.000000   0.500000    2.2447
# 81   AZ4JC4-YOIWhOOOSo0AcMw    38.0     10     3.800000   0.350000    0.8350
# 79   h_A7TFaKasHmrc9s_hhb5w    39.0     10     3.900000   0.362500    0.9994
# 85   cISQE8tQ29Q043hmY7LT2g    15.0      4     3.750000   0.343750    0.8269
# 59   tmtDPKSqypv7a9B84auDtQ    52.0     12     4.333333   0.416667    1.6101
# 101  MYD64NGYbF0n7sQZ-I4o5g     7.0      2     3.500000   0.312500    0.5930
# 43   8OiiPmyR8wvUsf7aX_b8mQ   150.0     31     4.838710   0.479839    2.3013
# 66   g83WbX_recywc4DEIZ-xug  2549.0    597     4.269682   0.408710    1.6025
# 37   EtNXaL2cOcrxQX8WUUhwsw   371.0     75     4.946667   0.493333    2.4849
# 93   P7umsPvXHXN3wanGOF4_6w    11.0      3     3.666667   0.333333    0.9137
# 78   M6-HvE8lj4tJgiJ6xO8Vhw   133.0     34     3.911765   0.363971    1.2662
# 103  ayOJSIl-P16HZAQBcQfUyQ   598.0    172     3.476744   0.309593    0.7405
# 105  EUWBT5GDxPC95w9itZ1EHw   811.0    235     3.451064   0.306383    0.8199
# 117  Zzl4ffV9kFY3yOSSgyRUBQ   316.0     98     3.224490   0.278061    0.6185
# 4    fzZtt9LF6bb1oqVX9xUoZg   105.0     21     5.000000   0.500000    2.8555
# 121  ER7lT5gKBN-WpNkSIChQAQ    41.0     13     3.153846   0.269231    0.6005
# 146  oecb2RmtclNABOZ1AIt-kg    25.0      9     2.777778   0.222222    0.1817
# 21   i42M5aLwhsCSRD0eWrp50g    15.0      3     5.000000   0.500000    2.9530
# 94   PooaRdu8Rxhs07tluNEF0g    11.0      3     3.666667   0.333333    1.3880
# 96   uBvHnQhoA80zxWk_08QkqA    11.0      3     3.666667   0.333333    1.3880
# 135  fWetLvfQXqpZcBQLHldUhA  1349.0    459     2.938998   0.242375    0.5165
#
#      geo_score     score
# 38    0.456399  0.949046
# 6     0.446003  0.946003
# 9     0.442779  0.942779
# 27    0.435025  0.935025
# 14    0.434513  0.934513
# 20    0.428758  0.928758
# 19    0.421687  0.921687
# 13    0.418322  0.918322
# 1     0.418322  0.918322
# 48    0.418322  0.885915
# 58    0.447008  0.864691
# 67    0.447480  0.854727
# 53    0.399028  0.852975
# 56    0.418322  0.846894
# 64    0.432123  0.842279
# 32    0.340471  0.840471
# 10    0.339778  0.839778
# 65    0.426478  0.835569
# 61    0.417197  0.833864
# 69    0.429200  0.829200
# 42    0.338352  0.820495
# 88    0.472359  0.816109
# 72    0.411131  0.803988
# 83    0.456459  0.802888
# 12    0.299110  0.799110
# 100   0.481077  0.793577
# 23    0.276732  0.776732
# 7     0.276732  0.776732
# 17    0.276732  0.776732
# 16    0.276732  0.776732
# 81    0.418322  0.768322
# 79    0.401810  0.764310
# 85    0.419136  0.762886
# 59    0.340471  0.757138
# 101   0.442629  0.755129
# 43    0.271047  0.750886
# 66    0.341235  0.749945
# 37    0.252606  0.745940
# 93    0.410418  0.743751
# 78    0.375013  0.738983
# 103   0.427814  0.737407
# 105   0.419839  0.726222
# 117   0.440067  0.718129
# 4     0.215383  0.715383
# 121   0.441875  0.711106
# 146   0.483940  0.706162
# 21    0.205590  0.705590
# 94    0.362779  0.696112
# 96    0.362779  0.696112
# 135   0.450312  0.692687

# %% [markdown]
# **Merge business informations**

# %%
rec_pop = business_details(business_df, rec_pop)

# %%
rec_pop
# Out:
#                business_id                                name  \
# 0   j6D75GAJu6LdvRR1_OsxnA                         Bridger Inn
# 1   ovFnrmsT5rUpbAQE1r-V0Q                    Segway Las Vegas
# 2   ER7lT5gKBN-WpNkSIChQAQ               Enterprise Rent-A-Car
# 3   i42M5aLwhsCSRD0eWrp50g                  Cowboy Trail Rides
# 4   MYD64NGYbF0n7sQZ-I4o5g       Las Vegas Club Hotel & Casino
# 5   EUWBT5GDxPC95w9itZ1EHw                 Garden Court Buffet
# 6   AZ4JC4-YOIWhOOOSo0AcMw                        Taxi Service
# 7   PWFB8WyJGaFBWfcrwcn9Lw                  Premier Club Tours
# 8   g83WbX_recywc4DEIZ-xug                         Neon Museum
# 9   h_A7TFaKasHmrc9s_hhb5w                        Place on 7th
# 10  diJLOTB7YfItRLcEr55MoQ                     Alibi Las Vegas
# 11  _Lm7t08Bnq_ai-nQkKO5lQ                  TOD Hotel & Hostel
# 12  PooaRdu8Rxhs07tluNEF0g                   Las Vegas LX Limo
# 13  tmtDPKSqypv7a9B84auDtQ            VIP Club Las Vegas Tours
# 14  vSrlrHuK_2DoGcGUPC9aqw   LuxuryPad: Superhost Housekeeping
# 15  8OiiPmyR8wvUsf7aX_b8mQ                Bike Blast Las Vegas
# 16  JcKtixWaFVOVR690WUiC-A                   Take A Hike Vegas
# 17  mSvclkxQVT6IpZOZ_OrByw            The Slingshot Experience
# 18  Zq7vhh8wnqPMoW1EXTeIzg                           AsterRIDE
# 19  ndTINKMlSIwMp6dEKVXeAg          Graffiti Art Gallery Alley
# 20  1qTx9z8RMz7RIYKAfnpZ0A              Lillie's Asian Cuisine
# 21  d6_UHGiMQb5_m8mi_tRc2Q                    Mermaid's Casino
# 22  cISQE8tQ29Q043hmY7LT2g  California Hotel-Casino & R V Park
# 23  AT4cfxVgGIy8vKY66ApU7g                           ABC Valet
# 24  ff-bUaqzSnyAOzW_Qtd65A             Las Vegas Walking Tours
# 25  8QWPlVQ6D-OExqXoaD2Z1g                   Vegas Pub Crawler
# 26  fzZtt9LF6bb1oqVX9xUoZg             Diplomat Exotic Rentals
# 27  8gYkL76weP9dmd-W8NOeqw                  The Hunt Las Vegas
# 28  fWetLvfQXqpZcBQLHldUhA                  The D Casino Hotel
# 29  ayOJSIl-P16HZAQBcQfUyQ           California Hotel & Casino
# 30  y0W8tP-ZRfGbYBzS_1FqeQ              Zappos Tour Experience
# 31  OIc8vVH1MTmObFeeoc0LFA                             SDX Bus
# 32  oecb2RmtclNABOZ1AIt-kg                             BoltBus
# 33  uBvHnQhoA80zxWk_08QkqA         Campervan North America LLC
# 34  Zzl4ffV9kFY3yOSSgyRUBQ              Binion's Gambling Hall
# 35  A_lTCKAfKQKhUiOUyx8-3A            Lady Luck Casino & Hotel
# 36  uAX_EAU1r6J3JwPeX7uGrA                         Vegas Hikes
# 37  i9rI_eLMlV6cowiZGVzh2Q           Bonneville Transit Center
# 38  EtNXaL2cOcrxQX8WUUhwsw                 Little Vegas Chapel
# 39  M6-HvE8lj4tJgiJ6xO8Vhw                          Hostel Cat
# 40  fAU948kCaESzxAD_nF7rYw                Vegas Republik Group
# 41  LklurWnK8agxFp6G-v1CMg                   Jake's Excursions
# 42  VPVV0W_loOx7M8wNAcRLtw                 You Can!! Segway HT
# 43  VG0nWxGsPixYLsyi49gyxQ                       Hugo's Cellar
# 44  fJTzF7HR7TaurZ475YZ86w                   Desert Moon Motel
# 45  ZU_BvNdn7GTytItF04POmg              Lake Mead Boat Rentals
# 46  CWh5Jvne98_jz0GO7hbzHw             Vegas Valley Food Tours
# 47  P7umsPvXHXN3wanGOF4_6w                    Trikke Las Vegas
# 48  cKgkSMcPXwWTzPrJRpa2qw                        Style N Dogz
# 49  fY0RCsymg465GQ7tmxLYog                        Promoter Now
#
#                                            categories  \
# 0   Hotels, Event Planning & Services, Hotels & Tr...
# 1   Tours, Motorcycle Rental, Hotels & Travel, Act...
# 2                         Hotels & Travel, Car Rental
# 3                              Hotels & Travel, Tours
# 4   Casinos, Hotels & Travel, Event Planning & Ser...
# 5   Restaurants, Hotels, Event Planning & Services...
# 6   Taxis, Tours, Hotels & Travel, Wine Tours, Tra...
# 7   Adult Entertainment, Nightlife, Bars, Party Bu...
# 8   Hotels & Travel, Shopping, Arts & Entertainmen...
# 9   Hotels & Travel, Event Planning & Services, Ho...
# 10  Active Life, Walking Tours, Food Tours, Perfor...
# 11  Event Planning & Services, Hotels, Hotels & Tr...
# 12      Limos, Transportation, Hotels & Travel, Taxis
# 13   Hotels & Travel, Nightlife, Walking Tours, Tours
# 14  Vacation Rental Agents, Hotels & Travel, Home ...
# 15  Hotels & Travel, Tours, Shopping, Mountain Bik...
# 16        Hiking, Tours, Active Life, Hotels & Travel
# 17  Tours, Car Rental, Motorcycle Rental, Hotels &...
# 18  Town Car Service, Buses, Hotels & Travel, Limo...
# 19  Hotels & Travel, Tours, Art Tours, Arts & Ente...
# 20  Hotels, Chinese, Casinos, Event Planning & Ser...
# 21  Desserts, Beer, Wine & Spirits, Bars, Hotels &...
# 22  Hotels & Travel, Arts & Entertainment, Casinos...
# 23  Valet Services, Event Planning & Services, Air...
# 24  Historical Tours, Tours, Walking Tours, Hotels...
# 25  Hotels & Travel, Bar Crawl, Nightlife, Arts & ...
# 26                 Hotels & Travel, Car Rental, Tours
# 27  Scavenger Hunts, Active Life, Hotels & Travel,...
# 28  Event Planning & Services, Hotels, Hotels & Tr...
# 29  Arts & Entertainment, Casinos, Hotels, Event P...
# 30  Hotels & Travel, Professional Services, Walkin...
# 31  Transportation, Hotels & Travel, Public Transp...
# 32  Transportation, Hotels & Travel, Public Transp...
# 33             RV Rental, Car Rental, Hotels & Travel
# 34  Event Planning & Services, Casinos, Hotels & T...
# 35  Arts & Entertainment, Hotels & Travel, Hotels,...
# 36  Active Life, Tours, Walking Tours, Hotels & Tr...
# 37  Public Transportation, Transportation, Hotels ...
# 38  Photographers, Wedding Planning, Wedding Chape...
# 39                           Hostels, Hotels & Travel
# 40     Local Flavor, Travel Services, Hotels & Travel
# 41  Hotels & Travel, Historical Tours, Active Life...
# 42                             Tours, Hotels & Travel
# 43  Seafood, American (Traditional), Arts & Entert...
# 44  Hotels & Travel, Hotels, Event Planning & Serv...
# 45  Boat Charters, Jet Skis, Tours, Active Life, E...
# 46  Tours, Food Tours, Walking Tours, Food, Histor...
# 47  Bike Rentals, Fitness & Instruction, Tours, Ac...
# 48  Pets, Hotels & Travel, Pet Transportation, Pet...
# 49  Nightlife, Tours, Party & Event Planning, Danc...
#
#                               address       city state   latitude   longitude  \
# 0                       301 S Main St  Las Vegas    NV  36.169008 -115.147637
# 1                       901 S Main St  Las Vegas    NV  36.161839 -115.151881
# 2                      301 Fremont St  Las Vegas    NV  36.170154 -115.142871
# 3                  1211 S Eastern Ave  Las Vegas    NV  36.156127 -115.118651
# 4                     18 E Fremont St  Las Vegas    NV  36.172075 -115.145689
# 5                       200 N Main St  Las Vegas    NV  36.174097 -115.145110
# 6                                      Las Vegas    NV  36.169941 -115.139830
# 7                100 S Las Vegas Blvd  Las Vegas    NV  36.168946 -115.141032
# 8            770 North Las Vegas Blvd  Las Vegas    NV  36.176986 -115.135346
# 9                          115 7th St  Las Vegas    NV  36.168895 -115.137570
# 10                     707 Fremont St  Las Vegas    NV  36.167543 -115.138423
# 11              1508 Las Vegas Blvd S  Las Vegas    NV  36.152970 -115.151883
# 12                    3832 W Reno Ave  Las Vegas    NV  36.175000 -115.136389
# 13                                     Las Vegas    NV  36.180000 -115.140000
# 14               150 N Las Vegas Blvd  Las Vegas    NV  36.169958 -115.139704
# 15      1818 S Industrial Rd, Ste 106  Las Vegas    NV  36.149457 -115.161596
# 16                                     Las Vegas    NV  36.169710 -115.123695
# 17  725 South Las Vegas Blvd, Ste 260  Las Vegas    NV  36.161205 -115.145457
# 18                                     Las Vegas    NV  36.169941 -115.139830
# 19                     1500 S Main St  Las Vegas    NV  36.153327 -115.154217
# 20                   129 E Fremont St  Las Vegas    NV  36.170040 -115.144798
# 21                      32 Fremont St  Las Vegas    NV  36.171450 -115.145281
# 22                      200 N Main St  Las Vegas    NV  36.174247 -115.145375
# 23                                     Las Vegas    NV  36.169710 -115.123695
# 24                    1 1/2 Main St S  Las Vegas    NV  36.172116 -115.146904
# 25                       201 N 3rd St  Las Vegas    NV  36.171829 -115.142318
# 26              2535 S Las Vegas Blvd  Las Vegas    NV  36.142326 -115.156148
# 27               628 S Las Vegas Blvd  Las Vegas    NV  36.162590 -115.145352
# 28                     301 Fremont St  Las Vegas    NV  36.169101 -115.143236
# 29                  12 East Ogden Ave  Las Vegas    NV  36.173216 -115.144837
# 30                    400 Stewart Ave  Las Vegas    NV  36.172699 -115.139272
# 31  600 S Grand Central Pkwy, Ste 350  Las Vegas    NV  36.164061 -115.154827
# 32                       500 S 1st St  Las Vegas    NV  36.165640 -115.148816
# 33                        4320 W Reno  Las Vegas    NV  36.175000 -115.136389
# 34                     128 Fremont St  Las Vegas    NV  36.171633 -115.144263
# 35                       206 N 3rd St  Las Vegas    NV  36.171719 -115.141505
# 36                                     Las Vegas    NV  36.169941 -115.139830
# 37               101 E Bonneville Ave  Las Vegas    NV  36.164614 -115.149001
# 38              2207 S Las Vegas Blvd  Las Vegas    NV  36.145687 -115.155757
# 39              1236 S Las Vegas Blvd  Las Vegas    NV  36.155912 -115.149753
# 40                                     Las Vegas    NV  36.169941 -115.139830
# 41                       917 S 1st St  Las Vegas    NV  36.161130 -115.151472
# 42                                     Las Vegas    NV  36.180000 -115.140000
# 43                     202 Fremont St  Las Vegas    NV  36.169849 -115.143368
# 44                    1701 Fremont St  Las Vegas    NV  36.163634 -115.126444
# 45               100 Callville Bay Rd  Las Vegas    NV  36.169710 -115.123695
# 46                                     Las Vegas    NV  36.169710 -115.123695
# 47                   707 E Fremont St  Las Vegas    NV  36.167717 -115.138353
# 48             703 North Racetrack Rd  Henderson    NV  36.169941 -115.139829
# 49      353 E Bonneville Ave, Ste 467  Las Vegas    NV  36.163486 -115.146521
#
#     stars  review_count     sum  count  ratings_avg  pop_score  distance  \
# 0     3.5            10    28.0      8     3.500000   0.312500    0.2102
# 1     5.0            38    70.0     14     5.000000   0.500000    0.6738
# 2     3.0            16    41.0     13     3.153846   0.269231    0.6005
# 3     5.0             5    15.0      3     5.000000   0.500000    2.9530
# 4     2.0            97     7.0      2     3.500000   0.312500    0.5930
# 5     3.5           556   811.0    235     3.451064   0.306383    0.8199
# 6     4.0            12    38.0     10     3.800000   0.350000    0.8350
# 7     4.5            47   137.0     32     4.281250   0.410156    0.6976
# 8     4.5           998  2549.0    597     4.269682   0.408710    1.6025
# 9     4.0            10    39.0     10     3.900000   0.362500    0.9994
# 10    4.5            54    58.0     14     4.142857   0.392857    0.9066
# 11    3.0             8     5.0      1     5.000000   0.500000    1.6170
# 12    2.5            10    11.0      3     3.666667   0.333333    1.3880
# 13    4.5            12    52.0     12     4.333333   0.416667    1.6101
# 14    4.5             6    26.0      6     4.333333   0.416667    0.8462
# 15    5.0            34   150.0     31     4.838710   0.479839    2.3013
# 16    5.0             4    20.0      4     5.000000   0.500000    2.2447
# 17    4.5             7    21.0      5     4.200000   0.400000    0.7267
# 18    4.5             7    31.0      7     4.428571   0.428571    0.8350
# 19    5.0            11    34.0      7     4.857143   0.482143    1.6312
# 20    3.5           104   132.0     35     3.771429   0.346429    0.4553
# 21    3.5           300   178.0     41     4.341463   0.417683    0.5494
# 22    3.5             5    15.0      4     3.750000   0.343750    0.8269
# 23    5.0             5     5.0      1     5.000000   0.500000    2.2447
# 24    5.0            16    65.0     13     5.000000   0.500000    0.5594
# 25    4.5            41    94.0     22     4.272727   0.409091    0.7538
# 26    5.0            21   105.0     21     5.000000   0.500000    2.8555
# 27    5.0             5    10.0      2     5.000000   0.500000    0.5915
# 28    3.0           951  1349.0    459     2.938998   0.242375    0.5165
# 29    3.5           445   598.0    172     3.476744   0.309593    0.7405
# 30    4.5            35    88.0     19     4.631579   0.453947    1.0271
# 31    4.0             5    10.0      2     5.000000   0.500000    0.6687
# 32    3.5            24    25.0      9     2.777778   0.222222    0.1817
# 33    3.5             8    11.0      3     3.666667   0.333333    1.3880
# 34    3.5           252   316.0     98     3.224490   0.278061    0.6185
# 35    3.0             9     5.0      1     5.000000   0.500000    0.8015
# 36    5.0             3    15.0      3     5.000000   0.500000    0.8350
# 37    3.5            16    15.0      4     3.750000   0.343750    0.2970
# 38    5.0           117   371.0     75     4.946667   0.493333    2.4849
# 39    3.5            59   133.0     34     3.911765   0.363971    1.2662
# 40    4.0             4     5.0      1     5.000000   0.500000    0.8350
# 41    5.0             7    35.0      7     5.000000   0.500000    0.7311
# 42    4.5             3     5.0      1     5.000000   0.500000    1.6101
# 43    4.5           888  1601.0    376     4.257979   0.407247    0.5447
# 44    5.0             3    15.0      3     5.000000   0.500000    2.0219
# 45    4.5             3    10.0      2     5.000000   0.500000    2.2447
# 46    5.0            30    45.0      9     5.000000   0.500000    2.2447
# 47    5.0            22    11.0      3     3.666667   0.333333    0.9137
# 48    5.0            25   128.0     27     4.740741   0.467593    0.8350
# 49    5.0            17    84.0     17     4.941176   0.492647    0.4559
#
#     geo_score     score
# 0    0.481077  0.793577
# 1    0.434513  0.934513
# 2    0.441875  0.711106
# 3    0.205590  0.705590
# 4    0.442629  0.755129
# 5    0.419839  0.726222
# 6    0.418322  0.768322
# 7    0.432123  0.842279
# 8    0.341235  0.749945
# 9    0.401810  0.764310
# 10   0.411131  0.803988
# 11   0.339778  0.839778
# 12   0.362779  0.696112
# 13   0.340471  0.757138
# 14   0.417197  0.833864
# 15   0.271047  0.750886
# 16   0.276732  0.776732
# 17   0.429200  0.829200
# 18   0.418322  0.846894
# 19   0.338352  0.820495
# 20   0.456459  0.802888
# 21   0.447008  0.864691
# 22   0.419136  0.762886
# 23   0.276732  0.776732
# 24   0.446003  0.946003
# 25   0.426478  0.835569
# 26   0.215383  0.715383
# 27   0.442779  0.942779
# 28   0.450312  0.692687
# 29   0.427814  0.737407
# 30   0.399028  0.852975
# 31   0.435025  0.935025
# 32   0.483940  0.706162
# 33   0.362779  0.696112
# 34   0.440067  0.718129
# 35   0.421687  0.921687
# 36   0.418322  0.918322
# 37   0.472359  0.816109
# 38   0.252606  0.745940
# 39   0.375013  0.738983
# 40   0.418322  0.918322
# 41   0.428758  0.928758
# 42   0.340471  0.840471
# 43   0.447480  0.854727
# 44   0.299110  0.799110
# 45   0.276732  0.776732
# 46   0.276732  0.776732
# 47   0.410418  0.743751
# 48   0.418322  0.885915
# 49   0.456399  0.949046

# %%
show_map(loc=engine_geo.get_current_location(), popularity=rec_pop)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id='content'></a>
# # 4. Content Based Keyword

# %% [markdown]
# [Back to menu](#menu)

# %% [markdown]
# ## 4.1 Methods

# %%
from nltk.tokenize import word_tokenize
import gensim
from gensim.models import Word2Vec
from nltk.corpus import stopwords
nltk.download('stopwords')
from sklearn.metrics.pairwise import cosine_similarity

data_path = "/home/hongphuc95/notebookteam/dataset/"
api_path = "/home/hongphuc95/notebookteam/api/"

class ContentExtact:

    def __init__(self, ye, business_df):
        self.ye = ye
        self.business_df = business_df

    ##########################################################
    #                     Loading tools                      #
    ##########################################################
    def load(self):
        self.load_text_to_vec()
        self.load_word2vec()

    ##########################################################
    #                    Text Processing                     #
    ##########################################################

    def clean_text(self, text):
        all_stopwords = stopwords.words('english')
        text_tokens = word_tokenize(text.lower())
        tokens_without_sw = [word for word in text_tokens if not word in all_stopwords]
        return tokens_without_sw

    def text_processing(self):
        logger.info("Cleaning text in progress...")
        start = time.time()
        review_df = pd.read_json(data_path + "cleaned/review_cleaned_2016_2019.json", lines=True)
        review_by_business = review_df.groupby('business_id')['text'].agg(lambda col: ' '.join(col)).reset_index()
        review_by_business["text"] = review_by_business["text"].apply(lambda x: self.clean_text(x))
        logger.info("Done cleaning text in %s seconds." % (time.time() - start))
        return review_by_business

    ##########################################################
    #                        Word2Vec                        #
    ##########################################################
    def train_word2vec(self, review_by_business=None, save=True):
        logger.info("Training Word2Vec Model in progress...")
        start = time.time()
        model = gensim.models.Word2Vec(review_by_business["text"], min_count=5, size=200, workers=4)
        logger.info("Done Word2Vec text in %s seconds." % (time.time() - start))
        self.model = model
        if save:
            self.save_word2vec(self.model)

    def save_word2vec(self, model):
        model.save(api_path + "trained/review_full.model")

    def load_word2vec(self):
        try:
            self.model = Word2Vec.load(api_path + "trained/review_full.model")
            logger.info("Reviews vectorized loaded")
        except (FileNotFoundError, IOError):
            self.model = None
            logger.info("File not found")

    ##########################################################
    #                        TextToVec                       #
    ##########################################################

    def text_to_vec(self, save=True):
        logger.info("Convert texts to vectors in progress...")
        start = time.time()
        self.load_word2vec()
        review_by_business = self.text_processing()

        if not self.model:
            self.train_word2vec(review_by_business=review_by_business, save=True)

        # Clean DF
        review_by_business["text_vec"] = review_by_business["text"].apply(
            lambda x: self.avg_feature_vector(x, model=self.model, n_features=200))

        review_by_business.drop("text", axis=1, inplace=True)
        if save:
            self.save_text_to_vec(review_by_business)
        self.docvecs = review_by_business
        logger.info("Done converting texts to vectors in %s seconds." % (time.time() - start))


    def save_text_to_vec(self, review_by_business):
        with open(api_path + "trained/review_2016_2019_full_vectorized.pickle", "wb") as f:
            pickle.dump(review_by_business, f, protocol=pickle.HIGHEST_PROTOCOL)

    def load_text_to_vec(self):
        try:
            with open(api_path + "trained/review_2016_2019_full_vectorized.pickle", "rb") as f:
                self.docvecs = pickle.load(f)
                logger.info("Reviews vectorized loaded")
        except (FileNotFoundError, IOError):
            self.text_to_vec()

    def avg_feature_vector(self, sentence, model, n_features):
        index2word_set = set(model.wv.index2word)
        feature_vec = np.zeros((n_features,), dtype='float32')
        n_words = 0
        for word in sentence:
            if word in index2word_set:
                n_words += 1
                feature_vec = np.add(feature_vec, model.wv[word])
        if (n_words > 0):
            feature_vec = np.divide(feature_vec, n_words)
        return feature_vec

    ##########################################################
    #                        Recommend                       #
    ##########################################################

    def keyword_recommend(self, input_str, top_n=20, filters={}, content_w=0.8, geo_w=0.2):
        docvecs = self.docvecs
        nearby_df = pd.DataFrame()

        if filters:
            mask = np.array([])
            if "nearby" in filters and not filters["nearby"].empty:
                nearby_df = filters["nearby"]
                nearby_ids = nearby_df["business_id"].values
                if mask.size == 0:
                    mask = nearby_ids
                else:
                    mask = np.intersect1d(mask, nearby_ids)

            if "categories" in filters and filters["categories"]:
                mask_cat = self.business_df[self.business_df["categories"].str.contains(filters["categories"])][
                    "business_id"].values
                if mask.size == 0:
                    mask = mask_cat
                else:
                    mask = np.intersect1d(mask, mask_cat)

            docvecs = docvecs[docvecs["business_id"].isin(mask)]

        from nltk.tokenize import word_tokenize
        input_vec = pd.DataFrame({"text": [input_str]})
        input_vec["text"] = input_vec["text"].apply(lambda x: word_tokenize(x.lower()))
        input_vec["text_vec"] = input_vec["text"].apply(
            lambda x: self.avg_feature_vector(x, model=self.model, n_features=200))
        business_similarity = docvecs[["business_id", "text_vec"]]

        # compute similarity array
        business_similarity["score"] = business_similarity["text_vec"].apply(
            lambda x: cosine_similarity([x], [input_vec["text_vec"].values[0]])[0][0])
        business_similarity = business_similarity.drop(columns=["text_vec"]).sort_values(ascending=False,
                                                                                         by="score")
        print("Shape business similarity before: %s" % (business_similarity.shape))
        if "nearby" in filters and not filters["nearby"].empty:
            business_similarity = business_similarity.rename(columns={"score": "content_score"})
            business_similarity = pd.merge(left=business_similarity, right=nearby_df, how="inner", on="business_id")
            business_similarity["score"] = content_w * business_similarity["content_score"] + geo_w * business_similarity["geo_score"]
            business_similarity = business_similarity.sort_values(by="score", ascending=False)            
            print("Shape business similarity after: %s" % (business_similarity))
            
        business_similarity = business_similarity.head(top_n)
        return business_similarity

    def business_similarity(self, business_ids, top_n, filters={}, content_w=0.8, geo_w=0.2):

        docvecs = self.docvecs
        businesses_similarity = pd.DataFrame()
        nearby_df = pd.DataFrame()

        mask = np.array([])
        if filters:
            if "nearby" in filters and not filters["nearby"].empty:
                nearby_df = filters["nearby"]
                nearby_ids = nearby_df["business_id"].values
                if mask.size == 0:
                    mask = nearby_ids
                else:
                    mask = np.intersect1d(mask, nearby_ids)

            if "categories" in filters and filters["categories"]:
                mask_cat = self.business_df[self.business_df["categories"].str.contains(filters["categories"])][
                    "business_id"].values
                business_ids = np.intersect1d(business_ids, mask_cat)
                print("hey")
                print(business_ids)
                if mask.size == 0:
                    mask = mask_cat
                else:
                    mask = np.intersect1d(mask, mask_cat)

        # Filter businesses in the area
        print("Mask size : %s" % (mask.size))
        if mask.size > 0:
            mask = np.append(mask, business_ids)
            docvecs = docvecs[docvecs["business_id"].isin(mask)]
        elif mask.size == 0:
            mask = business_ids
            docvecs = docvecs[docvecs["business_id"].isin(mask)]
        
        #When user has none of the review of the category that we're looking for
        if business_ids.size > 0:
            business_ids = business_ids[:5]

            for business_id in business_ids:
                business_similarity = pd.DataFrame()
                input_vec = docvecs[docvecs["business_id"] == business_id]
                business_similarity = docvecs[["business_id", "text_vec"]]

                # compute similarity array
                business_similarity["score"] = business_similarity["text_vec"].apply(
                    lambda x: cosine_similarity([x], [input_vec["text_vec"].values[0]])[0][0])
                business_similarity = business_similarity.drop(columns=["text_vec"]).sort_values(ascending=False,
                                                                                                 by="score")
                # Filter business with the same id
                business_similarity = business_similarity[~business_similarity["business_id"].isin(business_ids)]
                business_similarity["input_business_id"] = business_id

                if "nearby" in filters and not filters["nearby"].empty:
                    business_similarity = business_similarity.rename(columns={"score": "content_score"})
                    business_similarity = pd.merge(left=business_similarity, right=nearby_df, how="inner", on="business_id")
                    business_similarity["score"] = content_w * business_similarity["content_score"] + geo_w * \
                                                   business_similarity["geo_score"]
                    business_similarity = business_similarity.sort_values(by="score", ascending=False)
                business_similarity = business_similarity.head(top_n)

                businesses_similarity = businesses_similarity.append(business_similarity)

        return businesses_similarity

    def content_recommend(self, user_id, top_n, filters={}, content_w=0.8, geo_w=0.2):
        docvecs = self.docvecs

        mustArray = [
            self.ye.bodySingleMatch("user_id", user_id),
            self.ye.bodyRange("date", gteValue="2016-01-01", lteValue="2018-12-31"),
            self.ye.bodyRange("stars", gteValue="3")
        ]
        review_fisrt_chunk = self.ye.getComplexeQuery(index="yelp-review*",
                                                 mustArray=mustArray, filterArray=[],
                                                 exclude=["text", "@timestamp", "@version", "cool", "useful",
                                                          "funny"], size=2000)


        print("Total reviews retrieved: %d" % (review_fisrt_chunk["hits"]["total"]["value"]))
        review_df = self.ye.getResultScrolling(review_fisrt_chunk)
        review_df = review_df.sort_values(by="date", ascending=False)
        #review_df = alreadyreviwed(user_id=user_id, review_df=self.review_df)
        #review_df = review_df[review_df["stars"] >= 3].sort_values(by="date", ascending=False)

        # print("Businesses previously reviewed by user: ")
        # already_reviewed = business_details(self.business_df, review_df)
        # print(already_reviewed[["name", "business_id", "categories"]])

        business_reviewed_ids = review_df["business_id"].unique()
        sim_business_df = self.business_similarity(business_reviewed_ids, top_n=top_n, filters=filters, content_w=content_w, geo_w=geo_w)
        return business_reviewed_ids, sim_business_df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/hongphuc95/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
class EngineCB:

    def __init__(self, ye, business_df):
        logger.info("Initilizing Content Based Engine")
        self.content = ContentExtact(ye=ye, business_df=business_df)

    def load(self):
        self.content.load()

    def train_word2vec(self):
        self.train_word2vec()

    def train_texttovec(self):
        self.content.text_to_vec()

    def keyword_recommend(self, input_str, top_n=10, filters={}):
        return self.content.keyword_recommend(input_str=input_str, top_n=top_n, filters=filters)

    def content_recommend(self, user_id, top_n=10, filters={}):
        return self.content.content_recommend(user_id=user_id, top_n=top_n, filters=filters)

# %% [markdown]
# ## 4.2 Test

# %%
#hm = engine_cb.content_recommend(user_id="EC5nxNCWCmjHg1F14WrlxQ", nearby_businesses=business_ids_nearby, top_n=10)

# %%
filters={}
filters["nearby"] = business_nearby
filters["categories"] = "Tea"

# %%
engine_cb = EngineCB(ye=ye, business_df=business_df)
# Out:
# INFO:__main__:Initilizing Content Based Engine

# %%
engine_cb.load()
# Out:
# INFO:__main__:Reviews vectorized loaded
# INFO:gensim.utils:loading Word2Vec object from /home/hongphuc95/notebookteam/api/trained/review_full.model
# INFO:gensim.utils:loading wv recursively from /home/hongphuc95/notebookteam/api/trained/review_full.model.wv.* with mmap=None
# INFO:gensim.utils:loading vectors from /home/hongphuc95/notebookteam/api/trained/review_full.model.wv.vectors.npy with mmap=None
# INFO:gensim.utils:setting ignored attribute vectors_norm to None
# INFO:gensim.utils:loading vocabulary recursively from /home/hongphuc95/notebookteam/api/trained/review_full.model.vocabulary.* with mmap=None
# INFO:gensim.utils:loading trainables recursively from /home/hongphuc95/notebookteam/api/trained/review_full.model.trainables.* with mmap=None
# INFO:gensim.utils:loading syn1neg from /home/hongphuc95/notebookteam/api/trained/review_full.model.trainables.syn1neg.npy with mmap=None
# INFO:gensim.utils:setting ignored attribute cum_table to None
# INFO:gensim.utils:loaded /home/hongphuc95/notebookteam/api/trained/review_full.model
# INFO:__main__:Reviews vectorized loaded

# %%
#rec_cb = engine_cb.keyword_recommend(input_str="tacos", top_n=20, filters=filters)

# %%
reviewed_df, rec_cb = engine_cb.content_recommend(user_id="EC5nxNCWCmjHg1F14WrlxQ", top_n=20, filters=filters)
# Out:
# INFO:elasticsearch:POST http://47.91.72.40:9200/yelp-review*/_search?_source_excludes=text%2C%40timestamp%2C%40version%2Ccool%2Cuseful%2Cfunny&_source_includes=&scroll=1m&size=2000 [status:200 request:0.121s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.014s]
# Total reviews retrieved: 44
# hey
# ['DYAorbxOyubUB_wtQRCdug' 'eS76100l3h7Ollb5s3_M4A'
#  'hIUKufhwR6Ifn7bi0-phLA' 'hoskgfXQRZXc9HV48nVFvg'
#  's_Qrhr4aJnRX-m44DxYl_Q' 'yooVq4aUUthr7DOQiZ7yEA']
# Mask size : 166

# %%
rec_cb[rec_cb["input_business_id"] == "DYAorbxOyubUB_wtQRCdug"]
# Out:
#                business_id  content_score       input_business_id  distance  \
# 10  5iHctUjkQTGwEvOaBkwMRQ       0.934026  DYAorbxOyubUB_wtQRCdug    0.2408
# 2   Xspg78dOvuedvuPEUwZBjw       0.961518  DYAorbxOyubUB_wtQRCdug    0.8279
# 16  xnVkYE3iMp_aZniiCIuD0g       0.921127  DYAorbxOyubUB_wtQRCdug    0.4393
# 3   CoyeXg8FBsS_d20QzNIy-A       0.954577  DYAorbxOyubUB_wtQRCdug    1.1497
# 6   4Nj2ktP2NjCbv2aKeH3ZBg       0.950618  DYAorbxOyubUB_wtQRCdug    1.0789
# 9   be_HDTc0Gy6dKWoWq_o7UQ       0.934522  DYAorbxOyubUB_wtQRCdug    0.7659
# 12  0WPXDs4ini3D7jpiy1Daqw       0.931912  DYAorbxOyubUB_wtQRCdug    0.8504
# 19  L3dAvYkqMsLhyPLoeJgwsQ       0.916128  DYAorbxOyubUB_wtQRCdug    0.5800
# 5   0EgYXYjt2XJL4hlsKnzrcw       0.950762  DYAorbxOyubUB_wtQRCdug    1.4074
# 15  5B_Uo-PCaWu9Jio9BWHKXw       0.921425  DYAorbxOyubUB_wtQRCdug    0.9137
# 27  Ji35uFlQyOpKjMFNKwp4mw       0.896289  DYAorbxOyubUB_wtQRCdug    0.5263
# 30  IDBG5UhyqWU4YqB1MZZtNg       0.894455  DYAorbxOyubUB_wtQRCdug    0.7409
# 31  TXCARn0fvOFoydARXEeaJg       0.892892  DYAorbxOyubUB_wtQRCdug    0.7267
# 32  EiEaPRsi2AW3j3xraIssrA       0.891176  DYAorbxOyubUB_wtQRCdug    0.8506
# 37  Lc31HveLiuaxVEt0cvZO7Q       0.884047  DYAorbxOyubUB_wtQRCdug    0.7179
# 39  v_yCY6NCwxCPIsNZR80UfQ       0.882460  DYAorbxOyubUB_wtQRCdug    0.7270
# 53  K4z0ODOZNuN2uRnL4IwApw       0.860500  DYAorbxOyubUB_wtQRCdug    0.5156
# 57  UEuvtQTKNS0w53oJTrwS2Q       0.853879  DYAorbxOyubUB_wtQRCdug    0.3922
# 0   6UI3dCIY6eM1eBOsnEVBuw       0.975088  DYAorbxOyubUB_wtQRCdug    2.8484
# 50  065c76tt1dXBNmoGBymUgQ       0.866480  DYAorbxOyubUB_wtQRCdug    0.9277
#
#     geo_score     score
# 10   0.956007  0.938422
# 2    0.838071  0.936829
# 16   0.916133  0.920128
# 3    0.773428  0.918347
# 6    0.787650  0.918025
# 9    0.850525  0.917723
# 12   0.833551  0.912240
# 19   0.887869  0.910476
# 5    0.721661  0.904942
# 15   0.820835  0.901307
# 27   0.898656  0.896763
# 30   0.855547  0.886673
# 31   0.858400  0.885994
# 32   0.833511  0.879643
# 37   0.860168  0.879271
# 39   0.858340  0.877636
# 53   0.900806  0.868561
# 57   0.925594  0.868222
# 0    0.432193  0.866509
# 50   0.818023  0.856788

# %%
rec_cb = business_details(business_df, rec_cb)

# %%
rec_cb.head(40)
# Out:
#                business_id                          name  \
# 0   K4z0ODOZNuN2uRnL4IwApw                     Starbucks
# 1   K4z0ODOZNuN2uRnL4IwApw                     Starbucks
# 2   K4z0ODOZNuN2uRnL4IwApw                     Starbucks
# 3   fOq7DDqqsVm2XOFSL925XA                     Starbucks
# 4   IDBG5UhyqWU4YqB1MZZtNg                    Sambalatte
# 5   IDBG5UhyqWU4YqB1MZZtNg                    Sambalatte
# 6   IDBG5UhyqWU4YqB1MZZtNg                    Sambalatte
# 7   l4E8kiB13FWV1p_rGYJLig                       Bao Now
# 8   6UI3dCIY6eM1eBOsnEVBuw                      The Perq
# 9   6UI3dCIY6eM1eBOsnEVBuw                      The Perq
# 10  6UI3dCIY6eM1eBOsnEVBuw                      The Perq
# 11  UEuvtQTKNS0w53oJTrwS2Q             Sin City Sandwich
# 12  UEuvtQTKNS0w53oJTrwS2Q             Sin City Sandwich
# 13  UEuvtQTKNS0w53oJTrwS2Q             Sin City Sandwich
# 14  UEuvtQTKNS0w53oJTrwS2Q             Sin City Sandwich
# 15  065c76tt1dXBNmoGBymUgQ           Cheffini's Hot Dogs
# 16  065c76tt1dXBNmoGBymUgQ           Cheffini's Hot Dogs
# 17  065c76tt1dXBNmoGBymUgQ           Cheffini's Hot Dogs
# 18  065c76tt1dXBNmoGBymUgQ           Cheffini's Hot Dogs
# 19  maR6G8i3G6VGA7CaCQfz2w                     Starbucks
# 20  TXCARn0fvOFoydARXEeaJg         Pawn Donut and Coffee
# 21  TXCARn0fvOFoydARXEeaJg         Pawn Donut and Coffee
# 22  TXCARn0fvOFoydARXEeaJg         Pawn Donut and Coffee
# 23  TXCARn0fvOFoydARXEeaJg         Pawn Donut and Coffee
# 24  TXCARn0fvOFoydARXEeaJg         Pawn Donut and Coffee
# 25  CoyeXg8FBsS_d20QzNIy-A       Makers & Finders Coffee
# 26  CoyeXg8FBsS_d20QzNIy-A       Makers & Finders Coffee
# 27  CoyeXg8FBsS_d20QzNIy-A       Makers & Finders Coffee
# 28  CoyeXg8FBsS_d20QzNIy-A       Makers & Finders Coffee
# 29  CoyeXg8FBsS_d20QzNIy-A       Makers & Finders Coffee
# 30  kZspuWnM0Y-Losvk2Rl0lA  Cous Cous Mediterranean Cafe
# 31  kZspuWnM0Y-Losvk2Rl0lA  Cous Cous Mediterranean Cafe
# 32  SIWwh4m6kkvUaa5skrVAQQ    Jerry's Famous Coffee Shop
# 33  EiEaPRsi2AW3j3xraIssrA     Bronze Cafe at The Market
# 34  EiEaPRsi2AW3j3xraIssrA     Bronze Cafe at The Market
# 35  EiEaPRsi2AW3j3xraIssrA     Bronze Cafe at The Market
# 36  EiEaPRsi2AW3j3xraIssrA     Bronze Cafe at The Market
# 37  Qc0l8rZ3nvrcERitgxu8XA                  Omelet House
# 38  Qc0l8rZ3nvrcERitgxu8XA                  Omelet House
# 39  4lAwPgy1m9Rd0oBpi4Hr2w                    McDonald's
#
#                                            categories  \
# 0                                  Food, Coffee & Tea
# 1                                  Food, Coffee & Tea
# 2                                  Food, Coffee & Tea
# 3                                  Food, Coffee & Tea
# 4               Coffee & Tea, Food, Coffee Roasteries
# 5               Coffee & Tea, Food, Coffee Roasteries
# 6               Coffee & Tea, Food, Coffee Roasteries
# 7   Food, Coffee & Tea, Restaurants, Dim Sum, Chinese
# 8   Bakeries, Restaurants, Nightlife, Dance Clubs,...
# 9   Bakeries, Restaurants, Nightlife, Dance Clubs,...
# 10  Bakeries, Restaurants, Nightlife, Dance Clubs,...
# 11  Caterers, Sandwiches, Coffee & Tea, Restaurant...
# 12  Caterers, Sandwiches, Coffee & Tea, Restaurant...
# 13  Caterers, Sandwiches, Coffee & Tea, Restaurant...
# 14  Caterers, Sandwiches, Coffee & Tea, Restaurant...
# 15  Hot Dogs, Beer, Wine & Spirits, Restaurants, C...
# 16  Hot Dogs, Beer, Wine & Spirits, Restaurants, C...
# 17  Hot Dogs, Beer, Wine & Spirits, Restaurants, C...
# 18  Hot Dogs, Beer, Wine & Spirits, Restaurants, C...
# 19                                 Food, Coffee & Tea
# 20  Restaurants, Breakfast & Brunch, Food, Donuts,...
# 21  Restaurants, Breakfast & Brunch, Food, Donuts,...
# 22  Restaurants, Breakfast & Brunch, Food, Donuts,...
# 23  Restaurants, Breakfast & Brunch, Food, Donuts,...
# 24  Restaurants, Breakfast & Brunch, Food, Donuts,...
# 25  Cafes, Breakfast & Brunch, Coffee & Tea, Food,...
# 26  Cafes, Breakfast & Brunch, Coffee & Tea, Food,...
# 27  Cafes, Breakfast & Brunch, Coffee & Tea, Food,...
# 28  Cafes, Breakfast & Brunch, Coffee & Tea, Food,...
# 29  Cafes, Breakfast & Brunch, Coffee & Tea, Food,...
# 30  Mediterranean, Cafes, Coffee & Tea, Restaurant...
# 31  Mediterranean, Cafes, Coffee & Tea, Restaurant...
# 32  Bakeries, Coffee & Tea, Restaurants, Food, Bre...
# 33  Coffee & Tea, Restaurants, Vegan, Salad, Bagel...
# 34  Coffee & Tea, Restaurants, Vegan, Salad, Bagel...
# 35  Coffee & Tea, Restaurants, Vegan, Salad, Bagel...
# 36  Coffee & Tea, Restaurants, Vegan, Salad, Bagel...
# 37  Food, Restaurants, Coffee & Tea, American (Tra...
# 38  Food, Restaurants, Coffee & Tea, American (Tra...
# 39  Burgers, Convenience Stores, Fast Food, Food, ...
#
#                                               address             city state  \
# 0   129 East Fremont Street, Golden Nugget Las Veg...        Las Vegas    NV
# 1   129 East Fremont Street, Golden Nugget Las Veg...        Las Vegas    NV
# 2   129 East Fremont Street, Golden Nugget Las Veg...        Las Vegas    NV
# 3                                  122 East Clark Ave        Las Vegas    NV
# 4                                     100 N City Pkwy        Las Vegas    NV
# 5                                     100 N City Pkwy        Las Vegas    NV
# 6                                     100 N City Pkwy        Las Vegas    NV
# 7                                    300 W Sahara Ave        Las Vegas    NV
# 8                               2535 S Las Vegas Blvd        Las Vegas    NV
# 9                               2535 S Las Vegas Blvd        Las Vegas    NV
# 10                              2535 S Las Vegas Blvd        Las Vegas    NV
# 11                                      375 Lewis Ave        Las Vegas    NV
# 12                                      375 Lewis Ave        Las Vegas    NV
# 13                                      375 Lewis Ave        Las Vegas    NV
# 14                                      375 Lewis Ave        Las Vegas    NV
# 15                           707 Fremont St, Ste 1050        Las Vegas    NV
# 16                           707 Fremont St, Ste 1050        Las Vegas    NV
# 17                           707 Fremont St, Ste 1050        Las Vegas    NV
# 18                           707 Fremont St, Ste 1050        Las Vegas    NV
# 19                             1800 W Charleston Blvd        Las Vegas    NV
# 20                               725 S Las Vegas Blvd        Las Vegas    NV
# 21                               725 S Las Vegas Blvd        Las Vegas    NV
# 22                               725 S Las Vegas Blvd        Las Vegas    NV
# 23                               725 S Las Vegas Blvd        Las Vegas    NV
# 24                               725 S Las Vegas Blvd        Las Vegas    NV
# 25                            1120 S Main St, Ste 110        Las Vegas    NV
# 26                            1120 S Main St, Ste 110        Las Vegas    NV
# 27                            1120 S Main St, Ste 110        Las Vegas    NV
# 28                            1120 S Main St, Ste 110        Las Vegas    NV
# 29                            1120 S Main St, Ste 110        Las Vegas    NV
# 30                            450 Fremont St, Ste 123        Las Vegas    NV
# 31                            450 Fremont St, Ste 123        Las Vegas    NV
# 32                              1821 N Las Vegas Blvd  North Las Vegas    NV
# 33                                     611 Fremont St        Las Vegas    NV
# 34                                     611 Fremont St        Las Vegas    NV
# 35                                     611 Fremont St        Las Vegas    NV
# 36                                     611 Fremont St        Las Vegas    NV
# 37                      2160 W Charleston Blvd, Ste A        Las Vegas    NV
# 38                      2160 W Charleston Blvd, Ste A        Las Vegas    NV
# 39                                     301 Fremont St        Las Vegas    NV
#
#      latitude   longitude  stars  review_count  content_score  \
# 0   36.170871 -115.144920    3.0            79       0.860500
# 1   36.170871 -115.144920    3.0            79       0.841054
# 2   36.170871 -115.144920    3.0            79       0.897118
# 3   36.165913 -115.147520    3.5            33       0.836012
# 4   36.173917 -115.148725    4.0             6       0.894455
# 5   36.173917 -115.148725    4.0             6       0.888969
# 6   36.173917 -115.148725    4.0             6       0.894253
# 7   36.144152 -115.160106    3.5            40       0.885195
# 8   36.142369 -115.156034    3.5           104       0.975088
# 9   36.142369 -115.156034    3.5           104       0.983688
# 10  36.142369 -115.156034    3.5           104       0.961380
# 11  36.166596 -115.144224    4.5            48       0.853879
# 12  36.166596 -115.144224    4.5            48       0.852934
# 13  36.166596 -115.144224    4.5            48       0.903366
# 14  36.166596 -115.144224    4.5            48       0.868168
# 15  36.167799 -115.138203    4.0           214       0.866480
# 16  36.167799 -115.138203    4.0           214       0.862958
# 17  36.167799 -115.138203    4.0           214       0.885690
# 18  36.167799 -115.138203    4.0           214       0.883342
# 19  36.159323 -115.168029    3.5             3       0.895834
# 20  36.161205 -115.145457    4.0            51       0.892892
# 21  36.161205 -115.145457    4.0            51       0.905163
# 22  36.161205 -115.145457    4.0            51       0.889312
# 23  36.161205 -115.145457    4.0            51       0.780882
# 24  36.161205 -115.145457    4.0            51       0.833125
# 25  36.157897 -115.153959    4.5           961       0.954577
# 26  36.157897 -115.153959    4.5           961       0.956914
# 27  36.157897 -115.153959    4.5           961       0.968636
# 28  36.157897 -115.153959    4.5           961       0.912416
# 29  36.157897 -115.153959    4.5           961       0.889720
# 30  36.169639 -115.141065    3.5           288       0.899811
# 31  36.169639 -115.141065    3.5           288       0.905977
# 32  36.192999 -115.132463    3.5           162       0.902468
# 33  36.168290 -115.139128    4.5           150       0.891176
# 34  36.168290 -115.139128    4.5           150       0.893594
# 35  36.168290 -115.139128    4.5           150       0.966685
# 36  36.168290 -115.139128    4.5           150       0.913893
# 37  36.159478 -115.171222    4.5          1181       0.959036
# 38  36.159478 -115.171222    4.5          1181       0.927662
# 39  36.169919 -115.142933    2.0            19       0.833850
#
#          input_business_id  distance  geo_score     score
# 0   DYAorbxOyubUB_wtQRCdug    0.5156   0.900806  0.868561
# 1   eS76100l3h7Ollb5s3_M4A    0.5156   0.900806  0.853004
# 2   s_Qrhr4aJnRX-m44DxYl_Q    0.5156   0.900806  0.897855
# 3   s_Qrhr4aJnRX-m44DxYl_Q    0.1741   0.969406  0.862691
# 4   DYAorbxOyubUB_wtQRCdug    0.7409   0.855547  0.886673
# 5   eS76100l3h7Ollb5s3_M4A    0.7409   0.855547  0.882285
# 6   s_Qrhr4aJnRX-m44DxYl_Q    0.7409   0.855547  0.886512
# 7   hoskgfXQRZXc9HV48nVFvg    2.7717   0.447600  0.797676
# 8   DYAorbxOyubUB_wtQRCdug    2.8484   0.432193  0.866509
# 9   eS76100l3h7Ollb5s3_M4A    2.8484   0.432193  0.873389
# 10  s_Qrhr4aJnRX-m44DxYl_Q    2.8484   0.432193  0.855542
# 11  DYAorbxOyubUB_wtQRCdug    0.3922   0.925594  0.868222
# 12  eS76100l3h7Ollb5s3_M4A    0.3922   0.925594  0.867466
# 13  hIUKufhwR6Ifn7bi0-phLA    0.3922   0.925594  0.907812
# 14  hoskgfXQRZXc9HV48nVFvg    0.3922   0.925594  0.879653
# 15  DYAorbxOyubUB_wtQRCdug    0.9277   0.818023  0.856788
# 16  eS76100l3h7Ollb5s3_M4A    0.9277   0.818023  0.853971
# 17  hIUKufhwR6Ifn7bi0-phLA    0.9277   0.818023  0.872156
# 18  hoskgfXQRZXc9HV48nVFvg    0.9277   0.818023  0.870278
# 19  s_Qrhr4aJnRX-m44DxYl_Q    1.9612   0.610414  0.838750
# 20  DYAorbxOyubUB_wtQRCdug    0.7267   0.858400  0.885994
# 21  eS76100l3h7Ollb5s3_M4A    0.7267   0.858400  0.895810
# 22  hIUKufhwR6Ifn7bi0-phLA    0.7267   0.858400  0.883129
# 23  hoskgfXQRZXc9HV48nVFvg    0.7267   0.858400  0.796385
# 24  s_Qrhr4aJnRX-m44DxYl_Q    0.7267   0.858400  0.838180
# 25  DYAorbxOyubUB_wtQRCdug    1.1497   0.773428  0.918347
# 26  eS76100l3h7Ollb5s3_M4A    1.1497   0.773428  0.920217
# 27  hIUKufhwR6Ifn7bi0-phLA    1.1497   0.773428  0.929594
# 28  hoskgfXQRZXc9HV48nVFvg    1.1497   0.773428  0.884619
# 29  s_Qrhr4aJnRX-m44DxYl_Q    1.1497   0.773428  0.866462
# 30  hIUKufhwR6Ifn7bi0-phLA    0.7195   0.859846  0.891818
# 31  hoskgfXQRZXc9HV48nVFvg    0.7195   0.859846  0.896751
# 32  hoskgfXQRZXc9HV48nVFvg    3.2047   0.360620  0.794098
# 33  DYAorbxOyubUB_wtQRCdug    0.8506   0.833511  0.879643
# 34  eS76100l3h7Ollb5s3_M4A    0.8506   0.833511  0.881577
# 35  hIUKufhwR6Ifn7bi0-phLA    0.8506   0.833511  0.940050
# 36  hoskgfXQRZXc9HV48nVFvg    0.8506   0.833511  0.897816
# 37  hIUKufhwR6Ifn7bi0-phLA    2.2143   0.559571  0.879143
# 38  hoskgfXQRZXc9HV48nVFvg    2.2143   0.559571  0.854044
# 39  s_Qrhr4aJnRX-m44DxYl_Q    0.5821   0.887447  0.844569

# %%
show_map(loc=simulation_loc, contentbased=rec_content)

# %% [markdown]
# <a id='cf'></a>
# # 5. Collaorative Filtering

# %% [markdown]
# [Back to menu](#menu)

# %% [markdown]
# ## 5.1 Model Based SVD
# <a id='cf_model'></a>

# %%
review_df = pd.read_json(data_path + "cleaned/review_cleaned_2016_2019_Vegas.json", lines=True)

# %%
#review_df = pd.read_csv("/home/hongphuc95/notebookteam/fu/review.csv")

# %%
from scipy import sparse
from scipy.sparse.linalg import svds
from sklearn.preprocessing import LabelEncoder

class CustomSVD:
    def __init__(self, review_df):
        self.user_active_df = self.get_active_user(review_df)

    def get_active_user(self, review_df):
        n_active = 30
        user_review_df_count = review_df.groupby("user_id").size()
        user_review_active_values = user_review_df_count[user_review_df_count >= n_active].reset_index()[
            "user_id"].values
        user_active_df = review_df[review_df["user_id"].isin(user_review_active_values)]
        user_active_df = user_active_df.groupby(["user_id", "business_id"], as_index=False).mean()
        return user_active_df

    def create_utility_matrix(self, df):
        user_encoder = LabelEncoder()
        business_encoder = LabelEncoder()

        user_ids = pd.DataFrame(columns=["user_id_matrix"])
        business_ids = pd.DataFrame(columns=["business_id_matrix"])
        df["user_id_matrix"] = user_encoder.fit_transform(df['user_id'])
        df["business_id_matrix"] = business_encoder.fit_transform(df['business_id'])

        user_ids["user_id_matrix"] = df["user_id_matrix"].unique()
        business_ids["business_id_matrix"] = df["business_id_matrix"].unique()
        user_ids["user_id"] = user_encoder.inverse_transform(user_ids["user_id_matrix"])
        business_ids["business_id"] = business_encoder.inverse_transform(business_ids["business_id_matrix"])

        return df, user_ids, business_ids

    def create_sparse_matrix(self, user_active_matrix, user_ids, business_ids):
        highest_user_id = len(user_ids['user_id'].unique())
        highest_business_id = len(business_ids['business_id'].unique())
        shape_matrix = (highest_user_id, highest_business_id)
        ratings_mat = sparse.lil_matrix(shape_matrix)
        for i, row in user_active_matrix.iterrows():
            ratings_mat[row["user_id_matrix"], row["business_id_matrix"]] = row["stars"]
        return ratings_mat

    def svd_pred(self, ratings_mat, n_factor=15):
        U, sigma, Vt = svds(ratings_mat, k=n_factor)
        sigma = np.diag(sigma)
        all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt)

        # Normalization
        all_user_predicted_ratings_norm = (all_user_predicted_ratings - all_user_predicted_ratings.min()) / (
                all_user_predicted_ratings.max() - all_user_predicted_ratings.min())
        return all_user_predicted_ratings_norm

    def fit(self, n_factor=15):
        logger.info("Start building matrix")
        start = time.time()
        self.cf_preds_df = None

        user_active_matrix, self.user_ids, self.business_ids = self.create_utility_matrix(self.user_active_df)

        # self.cf_preds_df = None
        rating_mat = self.create_sparse_matrix(user_active_matrix, self.user_ids, self.business_ids)
        self.cf_preds_df = self.svd_pred(ratings_mat=rating_mat, n_factor=n_factor)
        logger.info("Matrix built in %s seconds." % (time.time() - start))

    def transform(self, user_id, filters={}, cf_w=0.8, geo_w=0.2, topn=1000):
        logger.info("Start predicting")
        start = time.time()
        recommendations_df = pd.DataFrame()

        user_id_num = self.user_ids[self.user_ids["user_id"] == user_id].user_id_matrix.values
        if user_id_num.size > 0:
            user_id_num = user_id_num.astype(int)[0]
            pred_user = self.cf_preds_df[user_id_num, :]
            sorted_user_predictions = pd.DataFrame(pred_user, columns=["score"])
            sorted_user_predictions = pd.merge(sorted_user_predictions, self.business_ids, left_index=True,
                                               right_on="business_id_matrix") \
                .drop(columns=["business_id_matrix"]) \
                .sort_values(ascending=False, by="score") \
                .reset_index(drop=True)

            items_to_ignore = self.user_active_df[self.user_active_df["user_id"] == user_id]
            items_to_ignore = items_to_ignore["business_id"].unique()

            # Recommend the highest predicted rating movies that the user hasn't seen yet.
            recommendations_df = sorted_user_predictions[~sorted_user_predictions['business_id'].isin(items_to_ignore)] \
                .sort_values('score', ascending=False)
        
                        
            if "nearby" in filters and not filters["nearby"].empty:
                nearby_df = filters["nearby"]
                recommendations_df = pd.merge(left=recommendations_df, right=nearby_df, how="inner", on="business_id")
                if not recommendations_df.empty:
                    recommendations_df = recommendations_df.rename(columns={"score": "cf_score"})
                    recommendations_df["score"] = cf_w * recommendations_df["cf_score"] + geo_w * recommendations_df["geo_score"]
                    recommendations_df = recommendations_df.sort_values(by="score", ascending=False)            
                
            recommendations_df = recommendations_df.head(topn)

            logger.info("Prediction done in %s seconds." % (time.time() - start))
            return items_to_ignore, recommendations_df
        else:
            logger.info("This user %s is not exist" % (user_id))
            return np.array([]), recommendations_df

    def rmse(self, true, pred):
        # this will be used towards the end
        x = true - pred
        return sum([xi * xi for xi in x]) / len(x)

# %%
class EngineCF:

    def __init__(self, business_df, review_df, ye):
        logger.info("Initilizing Collaborative Filtering Engine")
        self.business_df = business_df
        self.ye = ye
        self.model = CustomSVD(review_df=review_df)

    def train(self, n_factor=15):
        #user_active_df = self.init_user_df()
        self.model.fit(n_factor=n_factor)

    def predict(self, user_id, filters={}, topn=1000):
        return self.model.transform(user_id=user_id, filters=filters, topn=topn)

    def save_model(self):
        with open(api_path + "models/customsvd.model", "wb") as f:
            pickle.dump(self.model, f, protocol=pickle.HIGHEST_PROTOCOL)

    def load_model(self):
        try:
            with open(api_path + "models/customsvd.model", "rb") as f:
                self.model = pickle.load(f)
                logger.info("Custom SVD model loaded")
        except (FileNotFoundError, IOError):
            logger.info("File not found")

# %%
filters={}
filters["nearby"] = business_nearby

# %%
#train, test = train_test_split(user_active_df, test_size = 0.2)

# %%
engine_cf = EngineCF(business_df=business_df, review_df=review_df, ye=ye)
# Out:
# INFO:__main__:Initilizing Collaborative Filtering Engine

# %%
engine_cf.train()
# Out:
# INFO:__main__:Start building matrix
# INFO:__main__:Matrix built in 21.435007572174072 seconds.

# %%
# TODO Test --2vR0DIsmQ6WfcSzKWigw

# %%
engine_cf.predict(user_id="uU2B1vrqkpWJI30xoooabw", filters=filters, topn=50)
# Out:
# INFO:__main__:Start predicting
# INFO:__main__:Prediction done in 0.06001734733581543 seconds.
# (array(['-NR4KqS6lHseNvJ-GFzfMA', '0VjHFdczi6Nln_nn8bucJQ',
#         '31cOttU_tML5b6eLLXZfsQ', '3fT1kcQ-MVEImGHa3hll5w',
#         '6e0Abng1LRexKI4LRJTX_A', '7sb2FYLS2sejZKxRYF9mtg',
#         '9AnvV8V-UvA_rFhMCr_Dlw', 'A0X1baHPgw9IiBRivu0G9g',
#         'C2tt_-1YE4X2T7azXEF7IQ', 'D6K3VT6S8FwFm4u5uN8T8g',
#         'EZ4TljJvGenxrkM4JsqtZg', 'Gml97gSULiA6HFjie01d3Q',
#         'IZivKqtHyz4-ts8KsnvMrA', 'KDdu9HDswaJYExaGDuzRjQ',
#         'KkgnBZj3jRVjCY2H49JRaw', 'L6RxkP8dneVGelDLUhjCug',
#         'LIU7IcJtD9VieoIo__wd9Q', 'LPMZ9N1sAjs2nDx7DmiZ2w',
#         'NEZCr0zLIPNYWNF57KsJJQ', 'NLEe-RzDSU-5BN6xp_WWCw',
#         'NiQ_3tXqkoe6GaQ5w2sHaQ', 'Os1n1_idfw9vv9kwULGJnQ',
#         'Q-dVQgyof9paXKJLwFsn3Q', 'QCe_OTC_9Vf5-oQuflQH7Q',
#         'QUxY5s-cmQYgUPd2Dc_sOw', 'Rv1IiQaIIDunqzS8dSvHCw',
#         'S_5VQYMMa4aD3NzgYLkvhg', 'SqxIx0KbTmCvUlOfkjamew',
#         'TEpHybMZew9kKadvseEbEQ', 'TtqvXhjmXXd0nhibRAbpRg',
#         'VD0zZKG_ZEz_VYlKLtu9Zg', 'WrHu03srbhJAw6bnTIixdw',
#         'ZXfMiPsPv-cH7GMQ-5-mhA', 'ZrS5rhJ4OvXQG_38wPEWlA',
#         'b9lGo4hvKBFravd3iSNN9g', 'dqtWVr1WlaQcmPPCrmZH3w',
#         'e3PBfbtXUjMziX6XGsOMoA', 'fIewmXMJlsm7-fY335mtcg',
#         'fQt9QVAZM9PM0wFDdROvWw', 'grlL6zmHBOer9rPycsRhBA',
#         'gx2yPrOJSwF1ApJYdGBWIw', 'h3BoyKFgStjnBeKO-wLmIg',
#         'hPclwunHi36YV8cPghWJBg', 'iCQpiavjjPzJ5_3gPD5Ebg',
#         'iQrOVQFtcoV0itpyUPVuDQ', 'kPV1DlXSkcXY5G8r2LLmEA',
#         'lokPfoken16iTeAJ2PAwmQ', 'meG2hlQPCfeZ-JdvoG297g',
#         'mnU3iGsL55MCWXiWV3AcAQ', 'nTc-Qj_-ABZrpM9YSpJ6jA',
#         'ozEDKl0tZw5ob1evx41gcQ', 'phTLTkqSvylLkmz5wAwhTw',
#         'vjFZt8Rt3A3kY7yWh3qmgg', 'vktRU6PlvaCLoJEc_IADlg',
#         'x3R7O24Bf2zCd8NJxo9thw', 'zdE82PiD6wquvjYLyhOJNA'], dtype=object),
#        cf_score             business_id  distance  geo_score     score
#  405   0.354839  Vyadl8RsxaFaAFjm98lNTQ    0.0218   1.000000  0.483871
#  353   0.355003  VhazKK6zbHrdJaN-bmeHbQ    0.0361   0.997127  0.483428
#  1689  0.353774  3fdtp-bzoE4ZgTakkcEBzQ    0.0218   1.000000  0.483019
#  79    0.358837  ItqPtxnayraXSlBS0EMOgg    0.1243   0.979410  0.482951
#  96    0.358221  fOq7DDqqsVm2XOFSL925XA    0.1741   0.969406  0.480458
#  746   0.354242  j5pWQfzFuJdYUXb-vKHgyA    0.1157   0.981137  0.479621
#  274   0.355418  BDj5QLwCItRrEuMO2K25ag    0.1838   0.967457  0.477826
#  1963  0.353524  eRlyQbR4Wn7F6JH5dVs4Qg    0.1536   0.973524  0.477524
#  31    0.363821  r05kbKriZ3Z56Nre1WQIDg    0.3780   0.928447  0.476746
#  330   0.355103  kk9vGmlZNCdFuNC487YlBA    0.2519   0.953778  0.474838
#  665   0.354364  nyQsUIuE5hSPVbS4Z5O_UQ    0.2408   0.956007  0.474692
#  1335  0.353863  qeFE3hKVFsvBTV-geLSszg    0.2312   0.957936  0.474678
#  724   0.354273  5iHctUjkQTGwEvOaBkwMRQ    0.2408   0.956007  0.474619
#  777   0.354196  BoofbNU85LCG3pm9vpzk1A    0.2408   0.956007  0.474558
#  1027  0.354002  -zkn2p1mu9g-kbGNdM1lUA    0.2408   0.956007  0.474403
#  1534  0.353823  UyxVtMWnlfRlweWLlonCLw    0.2408   0.956007  0.474260
#  1788  0.353722  iUozl3nJ8rfYwff81Rsw2Q    0.2408   0.956007  0.474179
#  1351  0.353859  0lLaPO8KMPCkCMDjsVX5JA    0.2519   0.953778  0.473843
#  1463  0.353836  cOinUcaLy9bZyvnTWub96Q    0.2519   0.953778  0.473825
#  288   0.355337  Mtl7m4IBhVdr-LtQrKtScg    0.2846   0.947209  0.473711
#  294   0.355299  i9rI_eLMlV6cowiZGVzh2Q    0.2970   0.944718  0.473183
#  986   0.354028  ikq8TRpHxGxfBVFpmsnaNQ    0.2771   0.948715  0.472965
#  582   0.354489  pk5XeeqJ_00Ci769cV9RMg    0.2917   0.945783  0.472748
#  4     0.375025  v_yCY6NCwxCPIsNZR80UfQ    0.7270   0.858340  0.471688
#  1260  0.353884  bfxiPIVPQM-or8mElnDb7A    0.3278   0.938531  0.470814
#  760   0.354222  kJS1-c00AhTFF18OjJYeTA    0.3451   0.935056  0.470389
#  182   0.356283  BIBWGO_r_1znnlmLbp4Nxg    0.3879   0.926458  0.470318
#  227   0.355772  QRbIBAnX-5LnKZsKrrObUg    0.3809   0.927864  0.470190
#  951   0.354055  mvM_bCqtOhtNTQvaRRu0tw    0.3493   0.934212  0.470086
#  228   0.355747  KE-F3ZumDNwpTnCsOj6BLw    0.3955   0.924931  0.469584
#  8     0.371339  2iTsRqUsPGRH1li1WVRvKQ    0.7104   0.861674  0.469406
#  164   0.356448  3iQ4H1WRqg1EvSZSRLeb-A    0.4140   0.921215  0.469402
#  2086  0.352665  7SJoMX5ti-VoEsEW6mJLRA    0.3435   0.935377  0.469207
#  412   0.354829  9Zd5EssKJ-X6zA9aqfSZBQ    0.3879   0.926458  0.469155
#  106   0.357618  WKshNnFUI4uQee5kz6PUGg    0.4446   0.915068  0.469108
#  1777  0.353726  YfzPiY50h_10Sjlg3mnNWQ    0.3725   0.929551  0.468891
#  734   0.354256  DYNeABXl0-ZviedEXX-gUw    0.3855   0.926940  0.468793
#  1172  0.353914  FV6xh3cDXj6fVXi9vdfNIA    0.3804   0.927964  0.468724
#  659   0.354372  Ko-c15eutBBh3xhQ_NiauA    0.3908   0.925875  0.468673
#  615   0.354436  be_yaOiBVVHngU1jFQV2rA    0.3934   0.925353  0.468619
#  30    0.363872  cfggUk66F01Av4YWZJXcnA    0.5818   0.887507  0.468599
#  2022  0.353248  mS_dBSMFiDJn4UVc0iv6Hg    0.3755   0.928949  0.468388
#  581   0.354489  QeWUIRc20tt5kZ83BJAGyA    0.4146   0.921094  0.467810
#  1616  0.353805  Nom527WyF4fcyiK4FZsYRw    0.4012   0.923786  0.467801
#  474   0.354713  xnVkYE3iMp_aZniiCIuD0g    0.4393   0.916133  0.466997
#  232   0.355728  jJ2YgibOcokkyq4Rrwt1_A    0.4611   0.911753  0.466933
#  296   0.355292  C9uCpUVubFdAzLUpqvQHdg    0.4550   0.912979  0.466830
#  14    0.369662  3GEEy7RP6e4bT4LAiWFMFQ    0.7416   0.855407  0.466811
#  680   0.354338  kGqNxTmtKoax_jaStzAuWA    0.4424   0.915510  0.466572
#  607   0.354451  mqd1Aasl9aMqqa8CKjwEeQ    0.4450   0.914988  0.466558)

# %% [markdown]
# ## 5.2 Memory Based Friendlist
# <a id='cf_memory'></a>

# %%
class FriendSim:

    def __init__(self, ye):
        self.ye = ye
        
    def find_n_neighbours(self, df, nrows, n):
        if n>nrows:
            n = nrows
        order = np.argsort(df.values, axis=1)[:, :n]
        df = df.apply(lambda x: pd.Series(x.sort_values(ascending=False)
               .iloc[:n].index, 
              index=['top{}'.format(i) for i in range(1, n+1)]), axis=1)
        return df

    def standardize(self, row):
        new_row = (row - row.mean()) / (row.max() - row.min())
        return new_row

    def get_active_user(self, review_df, n_active=6):
        user_review_df_count = review_df.groupby("user_id").size()
        user_review_active_values = user_review_df_count[user_review_df_count >= n_active].reset_index()[
            "user_id"].values
        user_active_df = review_df[review_df["user_id"].isin(user_review_active_values)]
        user_active_df = user_active_df.groupby(["user_id", "business_id"], as_index=False).mean()
        return user_active_df

    def recommend(self, user_id):

        #Get friend of the user in the parameter
        mustArray = [
            self.ye.bodySingleMatch("user_id", user_id)
        ]
        include_list = ["name", "user_id", "friends", "yelping_since", "review_count",
                        "average_stars", "elite"]
        user_fisrt_chunk = self.ye.getComplexeQuery(index="yelp-user*",
                                                 mustArray=mustArray, filterArray=[],
                                                 include = include_list, size=2000)

        print("Total reviews retrieved: %d" % (user_fisrt_chunk["hits"]["total"]["value"]))
        user_df = self.ye.getResultScrolling(user_fisrt_chunk)
        friends_str = user_df["friends"].values[0]
        friends_list = np.unique(friends_str.split(", "))
        print("This user has %d friends" % (len(friends_list)))

        if friends_list.size > 0:
            friends_list = np.append(friends_list, np.array(user_id))
            mustArray = [
                self.ye.bodyMultivalueTerm("user_id.keyword", friends_list.tolist()),
                self.ye.bodyRange("date", gteValue="2016-01-01", lteValue="2018-12-31")

            ]
            review_fisrt_chunk = self.ye.getComplexeQuery(index="yelp-review*",
                                                     mustArray=mustArray, filterArray=[],
                                                     include=["user_id", "business_id", "stars"], size=2000)

            review_df = self.ye.getResultScrolling(review_fisrt_chunk)
            user_active_df = self.get_active_user(review_df=review_df)
            
            #check if user is still in user_active_df (cold start)
            if ( any(user_active_df.user_id== user_id) == False):
                return 1
            
            #retrieve all businesses seen by user to not recommend them later
            businesses_seen_by_user = user_active_df[user_active_df.user_id == user_id].business_id.unique()
            
            
            #************ old method *****************
            Mean = user_active_df.groupby(by="user_id",as_index=False)['stars'].mean()
            Mean.rename(columns={'stars': 'mean'}, inplace=True)
            Rating_avg = pd.merge(user_active_df,Mean,on='user_id')
            Rating_avg['adg_rating']=Rating_avg['stars']-Rating_avg['mean']
            
            #Building matrix by pivot table
            rating_mat = pd.pivot_table(
                data=Rating_avg,
                index="user_id",
                columns="business_id",
                values="stars",
                fill_value=0)
            
            rating_standardized = rating_mat.fillna(rating_mat.mean(axis=0))

#             #********** new method ****************
#             #Building matrix by pivot table
#             rating_mat = pd.pivot_table(
#                 data=user_active_df,
#                 index="user_id",
#                 columns="business_id",
#                 values="stars",
#                 fill_value=0)
#             rating_standardized = rating_mat.apply(self.standardize)
            
            nrows = rating_standardized.shape[0]
            item_similarity = cosine_similarity(rating_standardized)
            np.fill_diagonal(item_similarity, 0)
            item_similarity_df = pd.DataFrame(item_similarity, index=rating_mat.index, columns=rating_mat.index)
            sim_user_30_m = self.find_n_neighbours(item_similarity_df, nrows,30)
            
            # ******* justify user similarities **********
            neighbors_ids = sim_user_30_m[(sim_user_30_m.index.get_level_values('user_id') == user_id)].values.tolist()[0]
            justifications = pd.DataFrame()   
            for i in range (0,len(neighbors_ids)):
                common_restaurants = Rating_avg[Rating_avg.user_id == user_id].merge(Rating_avg[Rating_avg.user_id == neighbors_ids[i]],
                on = "business_id",
                how = "inner" )
                justifications = pd.concat([justifications, common_restaurants])
#             justifications = justifications.rename(columns = {'user_id_x':'user','user_id_y':'neighbor_id',
#                                                              'star_x':'stars_user', 'stars_y':'stars_neighbor'})
            test = justifications.groupby(by=["user_id_x","user_id_y"],as_index=False)['adg_rating_x','adg_rating_y'].mean()
            test.rename(columns={'adg_rating_x': 'user_avg','adg_rating_y': 'neighbor_avg'}, inplace=True)
            test['user_avg'] = test['user_avg'].map(lambda x: round(x,3))
            test['neighbor_avg'] = test['neighbor_avg'].map(lambda x: round(x,3))
            test['diff'] = abs(test['user_avg'] - test['neighbor_avg'])
            test = test.sort_values(by='diff',ascending=True)
            
            
            ###computing scores for each unseen business by user 
            business_user = Rating_avg.groupby(by = 'user_id')['business_id'].apply(lambda x:','.join(x))
            a = sim_user_30_m[sim_user_30_m.index==user_id].values
            b = a.squeeze().tolist()
            d = business_user[business_user.index.isin(b)]
            l = ','.join(d.values)
            businesses_seen_by_similar_users = l.split(',')
            businesses_under_consideration = list(set(businesses_seen_by_similar_users)-set(list(map(str, businesses_seen_by_user))))
            #businesses_under_consideration = list(map(int, businesses_under_consideration))
            score = []
            for item in businesses_under_consideration:
                c = rating_standardized.loc[:,item]
                d = c[c.index.isin(b)]
                f = d[d.notnull()]
                avg_user = Mean.loc[Mean['user_id'] == user_id,'mean'].values[0]
                index = f.index.values.squeeze().tolist()
                corr = item_similarity_df.loc[user_id,index]
                fin = pd.concat([f, corr], axis=1)
                fin.columns = ['adg_score','correlation']
                fin['score']=fin.apply(lambda x:x['adg_score'] * x['correlation'],axis=1)
                nume = fin['score'].sum()
                deno = fin['correlation'].sum()
                final_score = avg_user + (nume/deno)
                score.append(final_score)
            data = pd.DataFrame({'business_id':businesses_under_consideration,'score':score})
            top_recommendation = data.sort_values(by='score',ascending=False)
            ###noralize score between 0 and 1
            top_recommendation = top_recommendation.apply(lambda x: (x-min(x))/(max(x)-min(x)) if x.name == 'score' else x)
            return test

# %%
fs = FriendSim(ye=ye)

# %%
neighbors = fs.recommend(user_id="AyjqBovADgbskmLrIBOMlQ") #AyjqBovADgbskmLrIBOMlQ")
# pd_pvt = test[(test.index.get_level_values('user_id') == "AyjqBovADgbskmLrIBOMlQ")]
# pd_pvt
neighbors
# Out:
# INFO:elasticsearch:POST http://47.91.72.40:9200/yelp-user*/_search?_source_excludes=&_source_includes=name%2Cuser_id%2Cfriends%2Cyelping_since%2Creview_count%2Caverage_stars%2Celite&scroll=1m&size=2000 [status:200 request:0.016s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.014s]
# Total reviews retrieved: 1
# This user has 506 friends
# INFO:elasticsearch:POST http://47.91.72.40:9200/yelp-review*/_search?_source_excludes=&_source_includes=user_id%2Cbusiness_id%2Cstars&scroll=1m&size=2000 [status:200 request:0.201s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.141s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.144s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.141s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.144s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.140s]
# INFO:elasticsearch:POST http://47.91.72.40:9200/_search/scroll?scroll=1m [status:200 request:0.033s]
# /home/hongphuc95/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:109: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  user_id_x               user_id_y  user_avg  neighbor_avg  \
# 1   AyjqBovADgbskmLrIBOMlQ  60skTN6p8SdQ2sGNKL0vRQ    -0.002         0.044
# 22  AyjqBovADgbskmLrIBOMlQ  cg2P244yON3-_GXWkgAgsw     0.205         0.152
# 3   AyjqBovADgbskmLrIBOMlQ  8XKSiMpMxgdwI3qjuqmXFg     0.071         0.018
# 23  AyjqBovADgbskmLrIBOMlQ  fj-cFMD2qheCcv3FNvMcEg    -0.180        -0.120
# 27  AyjqBovADgbskmLrIBOMlQ  ve_Hbp67wIvWFNEiwV2vuw     0.161         0.100
# 9   AyjqBovADgbskmLrIBOMlQ  JtpZw-NLL5m6BNjd0LPQVQ    -0.128        -0.058
# 24  AyjqBovADgbskmLrIBOMlQ  hX0-0jfbXUNUTzyGtg090g    -0.017         0.087
# 11  AyjqBovADgbskmLrIBOMlQ  NhgU7RhuYYFmpkb1jlYJ6Q     0.142         0.246
# 16  AyjqBovADgbskmLrIBOMlQ  Yv7VHEZWLMmcBDvIlLh69w     0.150         0.039
# 28  AyjqBovADgbskmLrIBOMlQ  yyDp7MZ2st7p0fOQuFYpcA     0.170         0.283
# 8   AyjqBovADgbskmLrIBOMlQ  GOTjwdXD6bNZ-_qjY7GYYw     0.068        -0.049
# 21  AyjqBovADgbskmLrIBOMlQ  bLbSNkLggFnqwNNzzq-Ijw     0.039         0.195
# 14  AyjqBovADgbskmLrIBOMlQ  TprC8sujz8MkwuomrqUSiw     0.061         0.233
# 10  AyjqBovADgbskmLrIBOMlQ  LC_o79IQTseA2Qi41v_rMg     0.171         0.360
# 5   AyjqBovADgbskmLrIBOMlQ  EEAoUs1w38JHfHZMeSdqPQ    -0.017         0.192
# 13  AyjqBovADgbskmLrIBOMlQ  SDgrUDEdWNFBlC4ufVk1PQ    -0.148         0.086
# 17  AyjqBovADgbskmLrIBOMlQ  ZCLDdUi4px9mys8vVUeIkg     0.317         0.074
# 7   AyjqBovADgbskmLrIBOMlQ  FcWu03iLuGYGHbFXO556pA    -0.147         0.127
# 19  AyjqBovADgbskmLrIBOMlQ  ayp_-vbJPMa3LOTBulMvWA     0.094         0.375
# 15  AyjqBovADgbskmLrIBOMlQ  WJhQpdUHoFCtpU6gHFjVlQ     0.061         0.368
# 6   AyjqBovADgbskmLrIBOMlQ  FQbVI3UyKlL-HfQGcRF8aA     0.182        -0.137
# 25  AyjqBovADgbskmLrIBOMlQ  os-sDQoh-hCt2Lg76z6ZUA     0.261         0.585
# 4   AyjqBovADgbskmLrIBOMlQ  CQZpblGIHeMlD7KqNP7J7Q    -0.033         0.308
# 0   AyjqBovADgbskmLrIBOMlQ  1LrSW8RZ7gvXgnknqjd8fg     0.011         0.375
# 2   AyjqBovADgbskmLrIBOMlQ  7BOLcPyH4YmXGKm4sWaYKA    -0.072         0.429
# 20  AyjqBovADgbskmLrIBOMlQ  b7rchNJEp6Gaw0bHR-4s4g    -0.156         0.468
# 26  AyjqBovADgbskmLrIBOMlQ  tp77HGAm4JVX3BL50v7Ajg     0.761        -0.000
# 18  AyjqBovADgbskmLrIBOMlQ  aKosnyD1L-hRgEeXPJWwoQ     0.761        -0.056
# 29  AyjqBovADgbskmLrIBOMlQ  z8wN6EQuw_JF-zTjcNgsLw    -0.239         0.762
# 12  AyjqBovADgbskmLrIBOMlQ  Pub1A9LA1NSg7jNJjbUPJA    -0.572         0.507
#
#      diff
# 1   0.046
# 22  0.053
# 3   0.053
# 23  0.060
# 27  0.061
# 9   0.070
# 24  0.104
# 11  0.104
# 16  0.111
# 28  0.113
# 8   0.117
# 21  0.156
# 14  0.172
# 10  0.189
# 5   0.209
# 13  0.234
# 17  0.243
# 7   0.274
# 19  0.281
# 15  0.307
# 6   0.319
# 25  0.324
# 4   0.341
# 0   0.364
# 2   0.501
# 20  0.624
# 26  0.761
# 18  0.817
# 29  1.001
# 12  1.079

# %%
test
# Out:
#                  business_id     score
# 1907  L1-1P3acJc4gEFvWwjXcNQ  1.000000
# 1944  beuVp5CZxCdNvQIIPBS2rw  0.964212
# 1053  sZIVzaaEBp_HiYutZ2lWag  0.959333
# 1103  po0p6NIro0cDrmKkcyPy0w  0.941904
# 1428  YILyHegzhy1vlc_LNVfObw  0.904806
# ...                      ...       ...
# 628   MU1PQ5CWuV0OKKOeI7jx6Q  0.000374
# 179   RX8Q4_nu3VnAwXtHdgAKCg  0.000070
# 1391  VAD-Faox-xQdE1WdYn8_5Q  0.000000
# 639   vl2IZrNJEA8npSjqXbdwxw  0.000000
# 1113  BjrKNWhtQkedHw8hP_0Bjg  0.000000
#
# [2035 rows x 2 columns]

# %%
fs.find_n_neighbours(test, 30)
# Out:
#                                           top1                    top2  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  JtpZw-NLL5m6BNjd0LPQVQ  VxljrF5dBkgMm_C4aLJXlg
# -xDW3gYiYaoeVASXywTPgw  5OllWsrKJsYo3XQK6siRKA  WJhQpdUHoFCtpU6gHFjVlQ
# 0o8HUzggoNKay9-ZMj3HqQ  U9aadPV7mQXAbXiqXQ1jDg  HtHjamuBBMHsQgnP9s2ydA
# 17f-n5Rouu89FSKuc4c7xw  ZnznUorow2SkhWTT5saAxA  kOT_C9B-dGITaK_vpBeYNg
# 1LrSW8RZ7gvXgnknqjd8fg  Te7_l78PIzdfiu9ki3Jrbg  Z3S7Y6ywAOrWUS-jevfu6Q
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  2EuPAGalYnP7eSxPgFCNDg  D43OWyfzIQjL8feJpYh2SQ
# z4RytucxI_XfcMFaEI2DRg  J8yImoNCuugxr39znUJanA  iyI93tcSuQ54ckGyjaLP8g
# z8wN6EQuw_JF-zTjcNgsLw  WWLArhsfQz7C47CaPnudzQ  Yv7VHEZWLMmcBDvIlLh69w
# zW3PaTqR8fN-mnoYWk6Ymg  Rdt-JiAN7Qlw3dJ7UVdNtw  HtHjamuBBMHsQgnP9s2ydA
# zfDcvo9F7d9fAA_hWcBC5Q  U9aadPV7mQXAbXiqXQ1jDg  HtHjamuBBMHsQgnP9s2ydA
#
#                                           top3                    top4  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  RSLTG7N0wYJhRTW5CGEm5Q  q93KSB8PtxchdgcY17bH8Q
# -xDW3gYiYaoeVASXywTPgw  XOCyTfXy26xi4gZeun9v9w  UOTY05n5PmV7aARc7_UHIw
# 0o8HUzggoNKay9-ZMj3HqQ  sEAzELf3_F-8j49umuYyZg  qIJ2iA9JwRYZD0akh1nyRA
# 17f-n5Rouu89FSKuc4c7xw  U9aadPV7mQXAbXiqXQ1jDg  HtHjamuBBMHsQgnP9s2ydA
# 1LrSW8RZ7gvXgnknqjd8fg  yP4Xs0pRH8Uqn-BaEOmJFA  sjzv-c1k_HGGT9vZbfimWw
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  CqeLXgQUpMZNbz4GwBz87w  hX0-0jfbXUNUTzyGtg090g
# z4RytucxI_XfcMFaEI2DRg  -C-l8EHSLXtZZVfUAUhsPA  CqeLXgQUpMZNbz4GwBz87w
# z8wN6EQuw_JF-zTjcNgsLw  YB2SZbMgQHBOGOIsBK2Tkg  tp77HGAm4JVX3BL50v7Ajg
# zW3PaTqR8fN-mnoYWk6Ymg  U9aadPV7mQXAbXiqXQ1jDg  vvxIVr_OR6sHBzGPG9dRXg
# zfDcvo9F7d9fAA_hWcBC5Q  sEAzELf3_F-8j49umuYyZg  Te7_l78PIzdfiu9ki3Jrbg
#
#                                           top5                    top6  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  P4XUvN_8alI6dpTC_3LMkg  6ImN7CLRvsDnrAx6DF4nIw
# -xDW3gYiYaoeVASXywTPgw  CQZpblGIHeMlD7KqNP7J7Q  b7rchNJEp6Gaw0bHR-4s4g
# 0o8HUzggoNKay9-ZMj3HqQ  Te7_l78PIzdfiu9ki3Jrbg  dOj1z8X0sE0uyCmV1hTz3g
# 17f-n5Rouu89FSKuc4c7xw  sEAzELf3_F-8j49umuYyZg  YTl5q-1rvWGqtPs1bX7-hQ
# 1LrSW8RZ7gvXgnknqjd8fg  P4XUvN_8alI6dpTC_3LMkg  baW-EBVOGmLMuUgUdsiUpw
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  AyjqBovADgbskmLrIBOMlQ  bLbSNkLggFnqwNNzzq-Ijw
# z4RytucxI_XfcMFaEI2DRg  SDgrUDEdWNFBlC4ufVk1PQ  zfDcvo9F7d9fAA_hWcBC5Q
# z8wN6EQuw_JF-zTjcNgsLw  zfDcvo9F7d9fAA_hWcBC5Q  P4XUvN_8alI6dpTC_3LMkg
# zW3PaTqR8fN-mnoYWk6Ymg  rKdGiLfeE55TClso9GtjsA  iyI93tcSuQ54ckGyjaLP8g
# zfDcvo9F7d9fAA_hWcBC5Q  dOj1z8X0sE0uyCmV1hTz3g  VxljrF5dBkgMm_C4aLJXlg
#
#                                           top7                    top8  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  yyDp7MZ2st7p0fOQuFYpcA  Pub1A9LA1NSg7jNJjbUPJA
# -xDW3gYiYaoeVASXywTPgw  FQbVI3UyKlL-HfQGcRF8aA  60skTN6p8SdQ2sGNKL0vRQ
# 0o8HUzggoNKay9-ZMj3HqQ  w0W_hs1EX6x7XuZsEkHDDQ  qWeiidtgba1AbPBnwJfleA
# 17f-n5Rouu89FSKuc4c7xw  Te7_l78PIzdfiu9ki3Jrbg  w0W_hs1EX6x7XuZsEkHDDQ
# 1LrSW8RZ7gvXgnknqjd8fg  kOT_C9B-dGITaK_vpBeYNg  HtHjamuBBMHsQgnP9s2ydA
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  8XKSiMpMxgdwI3qjuqmXFg  -C-l8EHSLXtZZVfUAUhsPA
# z4RytucxI_XfcMFaEI2DRg  qIJ2iA9JwRYZD0akh1nyRA  8XKSiMpMxgdwI3qjuqmXFg
# z8wN6EQuw_JF-zTjcNgsLw  ZsjuEgOdvx9l5GKZdtwYIw  uc9ITBuspRFkl-S3Bo90dg
# zW3PaTqR8fN-mnoYWk6Ymg  sEAzELf3_F-8j49umuYyZg  w0W_hs1EX6x7XuZsEkHDDQ
# zfDcvo9F7d9fAA_hWcBC5Q  qWeiidtgba1AbPBnwJfleA  w0W_hs1EX6x7XuZsEkHDDQ
#
#                                           top9                   top10  ...  \
# user_id                                                                 ...
# -C-l8EHSLXtZZVfUAUhsPA  wdJKGY0xI5jpFrEL4Gm2fQ  HtHjamuBBMHsQgnP9s2ydA  ...
# -xDW3gYiYaoeVASXywTPgw  sjzv-c1k_HGGT9vZbfimWw  haSh72Q0MsQZUpWPeVgp0Q  ...
# 0o8HUzggoNKay9-ZMj3HqQ  ZnznUorow2SkhWTT5saAxA  VxljrF5dBkgMm_C4aLJXlg  ...
# 17f-n5Rouu89FSKuc4c7xw  dOj1z8X0sE0uyCmV1hTz3g  qWeiidtgba1AbPBnwJfleA  ...
# 1LrSW8RZ7gvXgnknqjd8fg  U9aadPV7mQXAbXiqXQ1jDg  ve_Hbp67wIvWFNEiwV2vuw  ...
# ...                                        ...                     ...  ...
# yyDp7MZ2st7p0fOQuFYpcA  KJRQUJEkWVebUImqc4vW_Q  QcckMs29Z47tuSyWDCMUlA  ...
# z4RytucxI_XfcMFaEI2DRg  yXzEJJaSRLgXfCzCWxRWGg  yyDp7MZ2st7p0fOQuFYpcA  ...
# z8wN6EQuw_JF-zTjcNgsLw  KJRQUJEkWVebUImqc4vW_Q  S5Eld1fZx6D8d9i5YbFOaA  ...
# zW3PaTqR8fN-mnoYWk6Ymg  Te7_l78PIzdfiu9ki3Jrbg  dOj1z8X0sE0uyCmV1hTz3g  ...
# zfDcvo9F7d9fAA_hWcBC5Q  ZnznUorow2SkhWTT5saAxA  UmzXKH73i8fixZBuB22oCw  ...
#
#                                          top21                   top22  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  dOj1z8X0sE0uyCmV1hTz3g  sEAzELf3_F-8j49umuYyZg
# -xDW3gYiYaoeVASXywTPgw  y4xrOPXEB75lJaLjr7Rtaw  VhkjxxBz-A4M-mMncpn1ZA
# 0o8HUzggoNKay9-ZMj3HqQ  X2Cf71Ab7EM9Yz4qJnAfug  6ImN7CLRvsDnrAx6DF4nIw
# 17f-n5Rouu89FSKuc4c7xw  S5Eld1fZx6D8d9i5YbFOaA  b7rchNJEp6Gaw0bHR-4s4g
# 1LrSW8RZ7gvXgnknqjd8fg  os-sDQoh-hCt2Lg76z6ZUA  qWeiidtgba1AbPBnwJfleA
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  wmyoMUiW6YU9Audm0lACDg  PVB0ggrspa1wWUECI7BN6w
# z4RytucxI_XfcMFaEI2DRg  ZsjuEgOdvx9l5GKZdtwYIw  wAJddqlvejbg1HHEPwWkjQ
# z8wN6EQuw_JF-zTjcNgsLw  w0W_hs1EX6x7XuZsEkHDDQ  jZUpqurVtlrN2QrgLxQzZw
# zW3PaTqR8fN-mnoYWk6Ymg  zfDcvo9F7d9fAA_hWcBC5Q  j2rFqYXfK8dN-CxULh6aUg
# zfDcvo9F7d9fAA_hWcBC5Q  qIJ2iA9JwRYZD0akh1nyRA  ve_Hbp67wIvWFNEiwV2vuw
#
#                                          top23                   top24  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  ZnznUorow2SkhWTT5saAxA  qWeiidtgba1AbPBnwJfleA
# -xDW3gYiYaoeVASXywTPgw  AyjqBovADgbskmLrIBOMlQ  RnTfhTi7VVEAMzlBXKvDsw
# 0o8HUzggoNKay9-ZMj3HqQ  hClOQIcmC_Tz-7n1VMRD1Q  KLUvRyRDUftXgFvUx50Kyg
# 17f-n5Rouu89FSKuc4c7xw  eZrS8SeTgX4c7ir3G1-8VQ  3ajSADFnm71e_Zcip_igWQ
# 1LrSW8RZ7gvXgnknqjd8fg  ZnznUorow2SkhWTT5saAxA  WWLArhsfQz7C47CaPnudzQ
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  CZnuW6YeZg7ZIiTbmI58BQ  BuKN22G8IY_rIuLLZ1Z9Xw
# z4RytucxI_XfcMFaEI2DRg  CZnuW6YeZg7ZIiTbmI58BQ  w0W_hs1EX6x7XuZsEkHDDQ
# z8wN6EQuw_JF-zTjcNgsLw  nrUQRMx6K-KJnoC15rMO2g  Te7_l78PIzdfiu9ki3Jrbg
# zW3PaTqR8fN-mnoYWk6Ymg  tp77HGAm4JVX3BL50v7Ajg  RArQt74He3Ok8asTRUw2FQ
# zfDcvo9F7d9fAA_hWcBC5Q  YTl5q-1rvWGqtPs1bX7-hQ  Rdt-JiAN7Qlw3dJ7UVdNtw
#
#                                          top25                   top26  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  8XKSiMpMxgdwI3qjuqmXFg  WWLArhsfQz7C47CaPnudzQ
# -xDW3gYiYaoeVASXywTPgw  hltCnxRt4SFkdQwOzgDN9A  U9aadPV7mQXAbXiqXQ1jDg
# 0o8HUzggoNKay9-ZMj3HqQ  wAJddqlvejbg1HHEPwWkjQ  YTl5q-1rvWGqtPs1bX7-hQ
# 17f-n5Rouu89FSKuc4c7xw  6ImN7CLRvsDnrAx6DF4nIw  qIJ2iA9JwRYZD0akh1nyRA
# 1LrSW8RZ7gvXgnknqjd8fg  VxljrF5dBkgMm_C4aLJXlg  UmzXKH73i8fixZBuB22oCw
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  KLUvRyRDUftXgFvUx50Kyg  NhgU7RhuYYFmpkb1jlYJ6Q
# z4RytucxI_XfcMFaEI2DRg  HtHjamuBBMHsQgnP9s2ydA  WJhQpdUHoFCtpU6gHFjVlQ
# z8wN6EQuw_JF-zTjcNgsLw  dOj1z8X0sE0uyCmV1hTz3g  ZnznUorow2SkhWTT5saAxA
# zW3PaTqR8fN-mnoYWk6Ymg  3ajSADFnm71e_Zcip_igWQ  FcWu03iLuGYGHbFXO556pA
# zfDcvo9F7d9fAA_hWcBC5Q  P4XUvN_8alI6dpTC_3LMkg  Pub1A9LA1NSg7jNJjbUPJA
#
#                                          top27                   top28  \
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  fExL6u06xTSg13k945IPAQ  BOQ_p0wtX8Xl9k2R9FBiBg
# -xDW3gYiYaoeVASXywTPgw  j2rFqYXfK8dN-CxULh6aUg  8Ae52apMLbD3jhHcaQ_Zzw
# 0o8HUzggoNKay9-ZMj3HqQ  ve_Hbp67wIvWFNEiwV2vuw  bzU8Cl6B9nqV1i5NReobvw
# 17f-n5Rouu89FSKuc4c7xw  Z3S7Y6ywAOrWUS-jevfu6Q  ve_Hbp67wIvWFNEiwV2vuw
# 1LrSW8RZ7gvXgnknqjd8fg  fExL6u06xTSg13k945IPAQ  J8yImoNCuugxr39znUJanA
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  Fv0e9RIV9jw5TX3ctA1WbA  SDgrUDEdWNFBlC4ufVk1PQ
# z4RytucxI_XfcMFaEI2DRg  Rdt-JiAN7Qlw3dJ7UVdNtw  VDsnV9Xc-akVbJC0hVtAQw
# z8wN6EQuw_JF-zTjcNgsLw  qWeiidtgba1AbPBnwJfleA  sEAzELf3_F-8j49umuYyZg
# zW3PaTqR8fN-mnoYWk6Ymg  6ImN7CLRvsDnrAx6DF4nIw  YTl5q-1rvWGqtPs1bX7-hQ
# zfDcvo9F7d9fAA_hWcBC5Q  yXzEJJaSRLgXfCzCWxRWGg  YB2SZbMgQHBOGOIsBK2Tkg
#
#                                          top29                   top30
# user_id
# -C-l8EHSLXtZZVfUAUhsPA  8drMKNHWavs2g6uf0pLtvg  UmzXKH73i8fixZBuB22oCw
# -xDW3gYiYaoeVASXywTPgw  S5Eld1fZx6D8d9i5YbFOaA  Y8adrWFzckrjuC11aAs9Og
# 0o8HUzggoNKay9-ZMj3HqQ  -C-l8EHSLXtZZVfUAUhsPA  P4XUvN_8alI6dpTC_3LMkg
# 17f-n5Rouu89FSKuc4c7xw  wAJddqlvejbg1HHEPwWkjQ  Rdt-JiAN7Qlw3dJ7UVdNtw
# 1LrSW8RZ7gvXgnknqjd8fg  QjZN6x1hGm2Edj95FfpKUA  KJRQUJEkWVebUImqc4vW_Q
# ...                                        ...                     ...
# yyDp7MZ2st7p0fOQuFYpcA  yyDp7MZ2st7p0fOQuFYpcA  rYPjqZO89ABei1fsZBSUbA
# z4RytucxI_XfcMFaEI2DRg  QSMsF78PxVYiAwwwHeZ7xA  S5Eld1fZx6D8d9i5YbFOaA
# z8wN6EQuw_JF-zTjcNgsLw  QSMsF78PxVYiAwwwHeZ7xA  fExL6u06xTSg13k945IPAQ
# zW3PaTqR8fN-mnoYWk6Ymg  YB2SZbMgQHBOGOIsBK2Tkg  qIJ2iA9JwRYZD0akh1nyRA
# zfDcvo9F7d9fAA_hWcBC5Q  kOT_C9B-dGITaK_vpBeYNg  0o8HUzggoNKay9-ZMj3HqQ
#
# [140 rows x 30 columns]

# %% [markdown]
# ## 5.3 Test

# %%
user_id = "EC5nxNCWCmjHg1F14WrlxQ"

# %%
to_ignore = engine_cf.already_review(user_id)

# %%
rec_cf = engine_cf.predict(user_id, items_to_ignore=to_ignore)

# %%
rec_cf = business_details(business_df, rec_cf)

# %%
rec_cf.head(5)

# %%
show_map(loc=simulation_loc, cf=rec_cf)

# %% [markdown]
# # 6. Hybrid

# %% [markdown]
# [Back to menu](#menu)

# %% [markdown]
# **Geolocation**

# %%
business_df_nearby.head(5)

# %% [markdown]
# **Popularity Based**

# %%
rec_pop[["business_id", "name", "categories", "score"]].head(5)

# %% [markdown]
# **Content Based**

# %%
rec_cb[["business_id", "name", "categories", "score"]].head(5)

# %% [markdown]
# **Collaborative Filtering**

# %%
rec_cf[["business_id", "name", "categories", "rec_score"]].head(5)

# %%
show_map(loc=simulation_loc, popularity=rec_pop, contentbased=rec_cb, cf=rec_cf)

# %% [markdown]
# ## 6.1 Compute weight
